# %% [markdown]
# ## Install Pakages and run the Libraries

# %%
#install.packages("mongolite")
#install.packages("config")
library(mongolite) # Create connection/Interface R<-> Mongodb
library(config)

# %% [markdown]
# ## Connect to MongoDB Atlas Database

# %% [markdown]
# ocllection: name of the collection to connect to. Defaults to "test".
# db: name of the database to connect to. Defaults to "test".
# url: address of the MongoDB server in standard URI Format.
# verbose: if TRUE, emits some extra output
# options: additional connection options such as SSL keys/cert

# %%
# Set the URL path with username, password and cluster url. 
# url_path = 'mongodb+srv://<username here>:<password here>!@<cluster url>/admin'


# using config to keep credientials safe, import the url 
url_path = config::get("url")

# Connect to the collection Ni-Based-Alloys from the Database Ni-Alloys using the above url path
# Verbose true would help display both warning and info 
 Ni <- mongo(collection = "Ni-Based-Alloys", db = "Ni-Alloys", 
               url = url_path, 
               verbose = TRUE)


print(Ni)
# Out:
# <Mongo collection> 'Ni-Based-Alloys'
#  $aggregate(pipeline = "{}", options = "{\"allowDiskUse\":true}", handler = NULL, pagesize = 1000, iterate = FALSE)
#  $count(query = "{}")
#  $disconnect(gc = TRUE)
#  $distinct(key, query = "{}")
#  $drop()
#  $export(con = stdout(), bson = FALSE, query = "{}", fields = "{}", sort = "{\"_id\":1}")
#  $find(query = "{}", fields = "{\"_id\":0}", sort = "{}", skip = 0, limit = 0, handler = NULL, pagesize = 1000)
#  $import(con, bson = FALSE)
#  $index(add = NULL, remove = NULL)
#  $info()
#  $insert(data, pagesize = 1000, stop_on_error = TRUE, ...)
#  $iterate(query = "{}", fields = "{\"_id\":0}", sort = "{}", skip = 0, limit = 0)
#  $mapreduce(map, reduce, query = "{}", sort = "{}", limit = 0, out = NULL, scope = NULL)
#  $remove(query, just_one = FALSE)
#  $rename(name, db = NULL)
#  $replace(query, update = "{}", upsert = FALSE)
#  $run(command = "{\"ping\": 1}", simplify = TRUE)
#  $update(query, update = "{\"$set\":{}}", filters = NULL, upsert = FALSE, multiple = FALSE)

# %% [markdown]
# ## Count the Amout of Records we have

# %%
Ni$count('{}')
# Out:
# [1] 144

# %% [markdown]
# ## Print Records

# %%
Ni$find('{}')
# Out:
#  Imported 144 records. Simplifying into dataframe...
#     Alloy             Ni       Co       Cr       Mo       W        Al
# 1   Standard TMS-75   59.9     12       3        2        6        6
# 2   y phase           52.05    17.85    5.87     3.41     6.23     2.4
# 3   y` phase          65.69    7.72     0.89     0.95     5.83     8.64
# 4   [001] Orientation Balance  NULL     8.39     NULL     9.47     5.47
# 5   USTB-F2           Bal.     7        2.8      NULL     5.7      6
# 6   USTB-F5           Bal.     7.1      2.9      NULL     5.7      6.1
# 7   USTB-F1           Bal.     7.0, 7.4 0        NULL     5.7, 1.9 5.9, 13.6
# 8   USTB-F2           Bal.     7.0, 7.3 2.8, 3.6 NULL     5.7, 1.9 6.0, 13.8
# 9   USTB-F3           Bal.     7.2, 7.6 5.7, 6.8 NULL     5.7, 1.9 5.8, 13.3
# 10  ReneN4            bal      8        9        2        6        3.7
# 11  ReneN5            bal      8        7        2        5        6.2
# 12  TMS-138           bal      5.8      2.9      2.9      5.9      5.9
# 13  LDS-0010          balance  0        0        12.02    NULL     6.08
# 14  LDS-0101          balance  9.76     0.01     7.01     NULL     6.01
# 15  LDS-5051          balance  0        2.35     9.01     NULL     6.03
# 16  LDS-5555          balance  4.91     2.43     9.48     NULL     6.03
# 17  LDS-4583          balance  5        3.9      8.1      NULL     6
# 18  LDS-4183          balance  9.97     3.93     8.13     NULL     6.05
# 19  LDS-4164          balance  11       4        6.1      NULL     6
# 20  LDS-1000          balance  0        4.79     7.08     NULL     6.04
# 21  LDS-1501          balance  4.98     4.93     7.13     NULL     6.01
# 22  LDS-1101          balance  9.9      4.7      7.1      NULL     6
# 23  LDS-1164          balance  10       4.9      6.1      NULL     6
# 24  LDS-1101+Hf       balance  10       5        7.3      NULL     6.1
# 25  LDS-1182          balance  9.99     4.88     8.19     NULL     5.99
# 26  LDS-1110          balance  9.76     4.68     11.95    NULL     5.98
# 27  DD6               Bal.     8.5      3.8      1.5      7        5.2
# 28  0Ru               Bal.     12       NULL     NULL     NULL     6
# 29  3Ru               Bal.     12       NULL     NULL     NULL     6
# 30  SC1111            Bal, Bal 7.1, 7.4 3.6, 4.3 1.0, 0.7 5.4, 1.9 6.0, 14.1
# ... ...               ...      ...      ...      ...      ...      ...
# 115 SC2122            NULL     NULL     NULL     NULL     NULL     NULL
# 116 NA                NULL     NULL     NULL     NULL     NULL     NULL
# 117 NA                NULL     NULL     NULL     NULL     NULL     NULL
# 118 NA                NULL     NULL     NULL     NULL     NULL     NULL
# 119 NA                NULL     NULL     NULL     NULL     NULL     NULL
# 120 NA                NULL     NULL     NULL     NULL     NULL     NULL
# 121 NA                NULL     NULL     NULL     NULL     NULL     NULL
# 122 NA                NULL     NULL     NULL     NULL     NULL     NULL
# 123 NA                NULL     NULL     NULL     NULL     NULL     NULL
# 124 IC21              NULL     NULL     NULL     NULL     NULL     NULL
# 125 NA                NULL     NULL     NULL     NULL     NULL     NULL
# 126 NA                NULL     NULL     NULL     NULL     NULL     NULL
# 127 NA                NULL     NULL     NULL     NULL     NULL     NULL
# 128 NA                NULL     NULL     NULL     NULL     NULL     NULL
# 129 NA                NULL     NULL     NULL     NULL     NULL     NULL
# 130 NA                NULL     NULL     NULL     NULL     NULL     NULL
# 131 NA                NULL     NULL     NULL     NULL     NULL     NULL
# 132 NA                NULL     NULL     NULL     NULL     NULL     NULL
# 133 NA                NULL     NULL     NULL     NULL     NULL     NULL
# 134 NA                NULL     NULL     NULL     NULL     NULL     NULL
# 135 NA                NULL     NULL     NULL     NULL     NULL     NULL
# 136 NA                NULL     NULL     NULL     NULL     NULL     NULL
# 137 NA                NULL     NULL     NULL     NULL     NULL     NULL
# 138 NA                NULL     NULL     NULL     NULL     NULL     NULL
# 139 0Ru               NULL     NULL     NULL     NULL     NULL     NULL
# 140 3Ru               NULL     NULL     NULL     NULL     NULL     NULL
# 141 0Ru               NULL     NULL     NULL     NULL     NULL     NULL
# 142 3Ru               NULL     NULL     NULL     NULL     NULL     NULL
# 143 TMS-2004          59.9     12       3        2        6        6
# 144 TMS-2004          59.9     12       3        2        6        6
#     Ta       Hf         Re       ... Misorientation Lifetime/h Rupture strain/%
# 1   6        0.1        5        ... NA             NA         NA
# 2   1.82     0.03       10.35    ... NA             NA         NA
# 3   9.06     0.15       1.07     ... NA             NA         NA
# 4   2.92     NULL       NULL     ... NA             NA         NA
# 5   8        NULL       4.7      ... NA             NA         NA
# 6   7.8      NULL       4.7      ... NA             NA         NA
# 7   7.8, 2.7 NULL       4.6, 1.5 ... NA             NA         NA
# 8   8.0, 2.7 NULL       4.7, 1.6 ... NA             NA         NA
# 9   8.1, 2.8 NULL       4.7, 1.6 ... NA             NA         NA
# 10  4        0          0        ... NA             NA         NA
# 11  7        0.2        3        ... NA             NA         NA
# 12  5.9      0.1        4.9      ... NA             NA         NA
# 13  6.14     0          0        ... NA             NA         NA
# 14  6.28     0          2.92     ... NA             NA         NA
# 15  6.11     0          2.99     ... NA             NA         NA
# 16  6.17     0          1.48     ... NA             NA         NA
# 17  6.3      0.2        3        ... NA             NA         NA
# 18  6.22     0.2        3.04     ... NA             NA         NA
# 19  6.2      0.2        4.1      ... NA             NA         NA
# 20  6.21     0          0        ... NA             NA         NA
# 21  6.26     0.19       3.05     ... NA             NA         NA
# 22  6.2      0          3        ... NA             NA         NA
# 23  6.3      0.2        4        ... NA             NA         NA
# 24  6.5      0.19       3.1      ... NA             NA         NA
# 25  6.25     0.22       2.03     ... NA             NA         NA
# 26  6.08     0          0        ... NA             NA         NA
# 27  6        NULL       1.6      ... NA             NA         NA
# 28  NULL     NULL       5.4      ... NA             NA         NA
# 29  NULL     NULL       5.4      ... NA             NA         NA
# 30  7.9, 2.8 0.10, 0.04 4.4, 1.4 ... NA             NA         NA
# ... ...      ...        ...          ...            ...        ...
# 115 NULL     NULL       NULL     ...  NA               NA        NA
# 116 NULL     NULL       NULL     ...  NA               NA        NA
# 117 NULL     NULL       NULL     ...  NA               NA        NA
# 118 NULL     NULL       NULL     ...  NA               NA        NA
# 119 NULL     NULL       NULL     ...  NA               NA        NA
# 120 NULL     NULL       NULL     ...  NA               NA        NA
# 121 NULL     NULL       NULL     ...  NA               NA        NA
# 122 NULL     NULL       NULL     ...  NA               NA        NA
# 123 NULL     NULL       NULL     ...  NA               NA        NA
# 124 NULL     NULL       NULL     ...  NA               NA        NA
# 125 NULL     NULL       NULL     ...  NA               NA        NA
# 126 NULL     NULL       NULL     ...  NA               NA        NA
# 127 NULL     NULL       NULL     ...  NA               NA        NA
# 128 NULL     NULL       NULL     ...  NA               NA        NA
# 129 NULL     NULL       NULL     ...  NA               NA        NA
# 130 NULL     NULL       NULL     ... 2.3            198.1      0.82
# 131 NULL     NULL       NULL     ... 3.1            208.9      1.50
# 132 NULL     NULL       NULL     ... 1.7            205.6      1.20
# 133 NULL     NULL       NULL     ... 1.6            224.2      0.75
# 134 NULL     NULL       NULL     ... 2.2            231.1      0.80
# 135 NULL     NULL       NULL     ... 3.1            236.4      0.82
# 136 NULL     NULL       NULL     ... 3.6            243.5      0.68
# 137 NULL     NULL       NULL     ... 2.9            285.7      0.80
# 138 NULL     NULL       NULL     ... 1.9            254.2      0.72
# 139 NULL     NULL       NULL     ...  NA               NA        NA
# 140 NULL     NULL       NULL     ...  NA               NA        NA
# 141 NULL     NULL       NULL     ...  NA               NA        NA
# 142 NULL     NULL       NULL     ...  NA               NA        NA
# 143 6        0.1        5        ...  NA               NA        NA
# 144 6        0.1        5        ...  NA               NA        NA
#     Elongation/% Reduction of area/% tfa (h) tsa (h) tta (h) ts/tf  tt/tf
# 1   NA           NA                  NA      NA      NA      NA     NA
# 2   NA           NA                  NA      NA      NA      NA     NA
# 3   NA           NA                  NA      NA      NA      NA     NA
# 4   NA           NA                  NA      NA      NA      NA     NA
# 5   NA           NA                  NA      NA      NA      NA     NA
# 6   NA           NA                  NA      NA      NA      NA     NA
# 7   NA           NA                  NA      NA      NA      NA     NA
# 8   NA           NA                  NA      NA      NA      NA     NA
# 9   NA           NA                  NA      NA      NA      NA     NA
# 10  NA           NA                  NA      NA      NA      NA     NA
# 11  NA           NA                  NA      NA      NA      NA     NA
# 12  NA           NA                  NA      NA      NA      NA     NA
# 13  NA           NA                  NA      NA      NA      NA     NA
# 14  NA           NA                  NA      NA      NA      NA     NA
# 15  NA           NA                  NA      NA      NA      NA     NA
# 16  NA           NA                  NA      NA      NA      NA     NA
# 17  NA           NA                  NA      NA      NA      NA     NA
# 18  NA           NA                  NA      NA      NA      NA     NA
# 19  NA           NA                  NA      NA      NA      NA     NA
# 20  NA           NA                  NA      NA      NA      NA     NA
# 21  NA           NA                  NA      NA      NA      NA     NA
# 22  NA           NA                  NA      NA      NA      NA     NA
# 23  NA           NA                  NA      NA      NA      NA     NA
# 24  NA           NA                  NA      NA      NA      NA     NA
# 25  NA           NA                  NA      NA      NA      NA     NA
# 26  NA           NA                  NA      NA      NA      NA     NA
# 27  NA           NA                  NA      NA      NA      NA     NA
# 28  NA           NA                  NA      NA      NA      NA     NA
# 29  NA           NA                  NA      NA      NA      NA     NA
# 30  NA           NA                  NA      NA      NA      NA     NA
# ... ...          ...                 ...     ...     ...     ...    ...
# 115   NA          NA                    NA      NA     NA    NA     NA
# 116   NA          NA                    NA      NA     NA    NA     NA
# 117   NA          NA                    NA      NA     NA    NA     NA
# 118   NA          NA                    NA      NA     NA    NA     NA
# 119   NA          NA                    NA      NA     NA    NA     NA
# 120   NA          NA                    NA      NA     NA    NA     NA
# 121   NA          NA                    NA      NA     NA    NA     NA
# 122   NA          NA                    NA      NA     NA    NA     NA
# 123   NA          NA                    NA      NA     NA    NA     NA
# 124   NA          NA                    NA      NA     NA    NA     NA
# 125   NA          NA                    NA      NA     NA    NA     NA
# 126   NA          NA                    NA      NA     NA    NA     NA
# 127   NA          NA                    NA      NA     NA    NA     NA
# 128   NA          NA                    NA      NA     NA    NA     NA
# 129   NA          NA                    NA      NA     NA    NA     NA
# 130 0.65         1.9                    NA      NA     NA    NA     NA
# 131 0.74         1.7                    NA      NA     NA    NA     NA
# 132 0.71         1.7                    NA      NA     NA    NA     NA
# 133 1.12         8.6                    NA      NA     NA    NA     NA
# 134 1.33         8.9                    NA      NA     NA    NA     NA
# 135 1.34         9.0                    NA      NA     NA    NA     NA
# 136 0.95         5.8                    NA      NA     NA    NA     NA
# 137 1.18         6.5                    NA      NA     NA    NA     NA
# 138 1.05         6.1                    NA      NA     NA    NA     NA
# 139   NA          NA                 156.9    77.9   55.7    49.60% 35.50%
# 140   NA          NA                 211.2   105.4   75.5    49.90% 35.70%
# 141   NA          NA                  80.1    18.4   54.5    23.00% 68.00%
# 142   NA          NA                 127.1    40.0   74.2    31.50% 58.40%
# 143   NA          NA                    NA      NA     NA    NA     NA
# 144   NA          NA                    NA      NA     NA    NA     NA

# %%
 print(Ni$find('{}'))
# Out:
#  Imported 144 records. Simplifying into dataframe...
#                 Alloy       Ni         Co       Cr       Mo        W        Al
# 1     Standard TMS-75     59.9         12        3        2        6         6
# 2             y phase    52.05      17.85     5.87     3.41     6.23       2.4
# 3            y` phase    65.69       7.72     0.89     0.95     5.83      8.64
# 4   [001] Orientation  Balance       NULL     8.39     NULL     9.47      5.47
# 5             USTB-F2     Bal.          7      2.8     NULL      5.7         6
# 6             USTB-F5     Bal.        7.1      2.9     NULL      5.7       6.1
# 7             USTB-F1     Bal.   7.0, 7.4        0     NULL 5.7, 1.9 5.9, 13.6
# 8             USTB-F2     Bal.   7.0, 7.3 2.8, 3.6     NULL 5.7, 1.9 6.0, 13.8
# 9             USTB-F3     Bal.   7.2, 7.6 5.7, 6.8     NULL 5.7, 1.9 5.8, 13.3
# 10             ReneN4      bal          8        9        2        6       3.7
# 11             ReneN5      bal          8        7        2        5       6.2
# 12            TMS-138      bal        5.8      2.9      2.9      5.9       5.9
# 13           LDS-0010  balance          0        0    12.02     NULL      6.08
# 14           LDS-0101  balance       9.76     0.01     7.01     NULL      6.01
# 15           LDS-5051  balance          0     2.35     9.01     NULL      6.03
# 16           LDS-5555  balance       4.91     2.43     9.48     NULL      6.03
# 17           LDS-4583  balance          5      3.9      8.1     NULL         6
# 18           LDS-4183  balance       9.97     3.93     8.13     NULL      6.05
# 19           LDS-4164  balance         11        4      6.1     NULL         6
# 20           LDS-1000  balance          0     4.79     7.08     NULL      6.04
# 21           LDS-1501  balance       4.98     4.93     7.13     NULL      6.01
# 22           LDS-1101  balance        9.9      4.7      7.1     NULL         6
# 23           LDS-1164  balance         10      4.9      6.1     NULL         6
# 24        LDS-1101+Hf  balance         10        5      7.3     NULL       6.1
# 25           LDS-1182  balance       9.99     4.88     8.19     NULL      5.99
# 26           LDS-1110  balance       9.76     4.68    11.95     NULL      5.98
# 27                DD6     Bal.        8.5      3.8      1.5        7       5.2
# 28                0Ru     Bal.         12     NULL     NULL     NULL         6
# 29                3Ru     Bal.         12     NULL     NULL     NULL         6
# 30             SC1111 Bal, Bal   7.1, 7.4 3.6, 4.3 1.0, 0.7 5.4, 1.9 6.0, 14.1
# 31             SC2111 Bal, Bal 15.0, 15.9 3.5, 4.2 1.0, 0.7 5.5, 1.9 6.1, 14.1
# 32             SC1211 Bal, Bal   6.9, 7.2 6.5, 7.7 1.0, 0.6 5.4, 1.8 6.0, 13.7
# 33             SC1121 Bal, Bal   6.9, 7.4 3.5, 4.2 2.4, 1.6 5.5, 1.9 6.0, 13.9
# 34             SC1112 Bal, Bal   6.9, 7.4 3.5, 4.3 1.0, 0.7 5.4, 1.9 6.0, 14.1
# 35             SC2212 Bal, Bal 14.4, 15.2 6.1, 7.3 1.0, 0.6 5.3, 1.8 6.0, 13.9
# 36             SC2122 Bal, Bal 14.5, 15.5 3.5, 4.2 2.4, 1.5 5.4, 1.9 6.1, 14.2
# 37            USTB-F2     NULL       NULL     NULL     NULL     NULL      NULL
# 38            USTB-F5     NULL       NULL     NULL     NULL     NULL      NULL
# 39            USTB-F2     NULL       NULL     NULL     NULL     NULL      NULL
# 40            USTB-F5     NULL       NULL     NULL     NULL     NULL      NULL
# 41            USTB-F1     NULL        9.2        0     NULL      2.1       8.2
# 42            USTB-F1     NULL        5.9        0     NULL      1.7      15.4
# 43            USTB-F1     NULL       1.56        0     NULL     1.24      0.53
# 44            USTB-F1     NULL        8.2        0     NULL        2       9.2
# 45            USTB-F1     NULL        5.1        0     NULL      1.5      16.6
# 46            USTB-F1     NULL       1.61        0     NULL     1.33      0.55
# 47            USTB-F2     NULL        9.2      4.9     NULL      2.3       8.2
# 48            USTB-F2     NULL        6.2      2.8     NULL      1.7      15.2
# 49            USTB-F2     NULL       1.48     1.75     NULL     1.35      0.54
# 50            USTB-F2     NULL        7.9      4.4     NULL        2       8.9
# 51            USTB-F2     NULL        4.8      1.9     NULL      1.6      16.8
# 52            USTB-F2     NULL       1.65     2.32     NULL     1.25      0.53
# 53            USTB-F3     NULL        9.4      8.6     NULL      2.2       8.3
# 54            USTB-F3     NULL          6      3.7     NULL      1.7      15.7
# 55            USTB-F3     NULL       1.57     2.32     NULL     1.29      0.53
# 56            USTB-F3     NULL        8.1      7.5     NULL        2         9
# 57            USTB-F3     NULL        4.8      3.3     NULL      1.6      16.4
# 58            USTB-F3     NULL       1.69     2.27     NULL     1.25      0.55
# 59            USTB-F1     NULL       NULL     NULL     NULL     NULL      NULL
# 60            USTB-F1     NULL       NULL     NULL     NULL     NULL      NULL
# 61            USTB-F2     NULL       NULL     NULL     NULL     NULL      NULL
# 62            USTB-F2     NULL       NULL     NULL     NULL     NULL      NULL
# 63            USTB-F3     NULL       NULL     NULL     NULL     NULL      NULL
# 64            USTB-F3     NULL       NULL     NULL     NULL     NULL      NULL
# 65            USTB-F1     NULL       NULL     NULL     NULL     NULL      NULL
# 66            USTB-F2     NULL       NULL     NULL     NULL     NULL      NULL
# 67            USTB-F3     NULL       NULL     NULL     NULL     NULL      NULL
# 68             ReneN4     NULL       NULL     NULL     NULL     NULL      NULL
# 69             ReneN5     NULL       NULL     NULL     NULL     NULL      NULL
# 70            TMS-138     NULL       NULL     NULL     NULL     NULL      NULL
# 71             ReneN4     NULL       NULL     NULL     NULL     NULL      NULL
# 72             ReneN5     NULL       NULL     NULL     NULL     NULL      NULL
# 73            TMS-138     NULL       NULL     NULL     NULL     NULL      NULL
# 74             ReneN4     NULL       NULL     NULL     NULL     NULL      NULL
# 75             ReneN5     NULL       NULL     NULL     NULL     NULL      NULL
# 76            TMS-138     NULL       NULL     NULL     NULL     NULL      NULL
# 77           LDS-0010     NULL       NULL     NULL     NULL     NULL      NULL
# 78           LDS-0101     NULL       NULL     NULL     NULL     NULL      NULL
# 79           LDS-5051     NULL       NULL     NULL     NULL     NULL      NULL
# 80           LDS-5555     NULL       NULL     NULL     NULL     NULL      NULL
# 81           LDS-4583     NULL       NULL     NULL     NULL     NULL      NULL
# 82           LDS-4183     NULL       NULL     NULL     NULL     NULL      NULL
# 83           LDS-4164     NULL       NULL     NULL     NULL     NULL      NULL
# 84           LDS-1000     NULL       NULL     NULL     NULL     NULL      NULL
# 85          LDS-1501a     NULL       NULL     NULL     NULL     NULL      NULL
# 86           LDS-1101     NULL       NULL     NULL     NULL     NULL      NULL
# 87           LDS-1164     NULL       NULL     NULL     NULL     NULL      NULL
# 88        LDS-1101+Hf     NULL       NULL     NULL     NULL     NULL      NULL
# 89          LDS-1182a     NULL       NULL     NULL     NULL     NULL      NULL
# 90          LDS-1110b     NULL       NULL     NULL     NULL     NULL      NULL
# 91           LDS-0010     NULL       NULL     NULL     NULL     NULL      NULL
# 92           LDS-0101     NULL       NULL     NULL     NULL     NULL      NULL
# 93           LDS-5051     NULL       NULL     NULL     NULL     NULL      NULL
# 94           LDS-5555     NULL       NULL     NULL     NULL     NULL      NULL
# 95           LDS-4583     NULL       NULL     NULL     NULL     NULL      NULL
# 96           LDS-4183     NULL       NULL     NULL     NULL     NULL      NULL
# 97           LDS-4164     NULL       NULL     NULL     NULL     NULL      NULL
# 98           LDS-1000     NULL       NULL     NULL     NULL     NULL      NULL
# 99           LDS-1501     NULL       NULL     NULL     NULL     NULL      NULL
# 100          LDS-1101     NULL       NULL     NULL     NULL     NULL      NULL
# 101          LDS-1164     NULL       NULL     NULL     NULL     NULL      NULL
# 102       LDS-1101+Hf     NULL       NULL     NULL     NULL     NULL      NULL
# 103          LDS-1182     NULL       NULL     NULL     NULL     NULL      NULL
# 104          LDS-1110     NULL       NULL     NULL     NULL     NULL      NULL
# 105           Alloy 1     NULL       NULL     NULL     NULL     NULL      NULL
# 106           Alloy 2     NULL       NULL     NULL     NULL     NULL      NULL
# 107           Alloy 1     NULL       NULL     NULL     NULL     NULL      NULL
# 108           Alloy 2     NULL       NULL     NULL     NULL     NULL      NULL
# 109            SC1111     NULL       NULL     NULL     NULL     NULL      NULL
# 110            SC2111     NULL       NULL     NULL     NULL     NULL      NULL
# 111            SC1211     NULL       NULL     NULL     NULL     NULL      NULL
# 112            SC1121     NULL       NULL     NULL     NULL     NULL      NULL
# 113            SC1112     NULL       NULL     NULL     NULL     NULL      NULL
# 114            SC2212     NULL       NULL     NULL     NULL     NULL      NULL
# 115            SC2122     NULL       NULL     NULL     NULL     NULL      NULL
# 116              <NA>     NULL       NULL     NULL     NULL     NULL      NULL
# 117              <NA>     NULL       NULL     NULL     NULL     NULL      NULL
# 118              <NA>     NULL       NULL     NULL     NULL     NULL      NULL
# 119              <NA>     NULL       NULL     NULL     NULL     NULL      NULL
# 120              <NA>     NULL       NULL     NULL     NULL     NULL      NULL
# 121              <NA>     NULL       NULL     NULL     NULL     NULL      NULL
# 122              <NA>     NULL       NULL     NULL     NULL     NULL      NULL
# 123              <NA>     NULL       NULL     NULL     NULL     NULL      NULL
# 124              IC21     NULL       NULL     NULL     NULL     NULL      NULL
# 125              <NA>     NULL       NULL     NULL     NULL     NULL      NULL
# 126              <NA>     NULL       NULL     NULL     NULL     NULL      NULL
# 127              <NA>     NULL       NULL     NULL     NULL     NULL      NULL
# 128              <NA>     NULL       NULL     NULL     NULL     NULL      NULL
# 129              <NA>     NULL       NULL     NULL     NULL     NULL      NULL
# 130              <NA>     NULL       NULL     NULL     NULL     NULL      NULL
# 131              <NA>     NULL       NULL     NULL     NULL     NULL      NULL
# 132              <NA>     NULL       NULL     NULL     NULL     NULL      NULL
# 133              <NA>     NULL       NULL     NULL     NULL     NULL      NULL
# 134              <NA>     NULL       NULL     NULL     NULL     NULL      NULL
# 135              <NA>     NULL       NULL     NULL     NULL     NULL      NULL
# 136              <NA>     NULL       NULL     NULL     NULL     NULL      NULL
# 137              <NA>     NULL       NULL     NULL     NULL     NULL      NULL
# 138              <NA>     NULL       NULL     NULL     NULL     NULL      NULL
# 139               0Ru     NULL       NULL     NULL     NULL     NULL      NULL
# 140               3Ru     NULL       NULL     NULL     NULL     NULL      NULL
# 141               0Ru     NULL       NULL     NULL     NULL     NULL      NULL
# 142               3Ru     NULL       NULL     NULL     NULL     NULL      NULL
# 143          TMS-2004     59.9         12        3        2        6         6
# 144          TMS-2004     59.9         12        3        2        6         6
#             Ta         Hf       Re        Source
# 1            6        0.1        5 2004 Murakumo
# 2         1.82       0.03    10.35 2004 Murakumo
# 3         9.06       0.15     1.07 2004 Murakumo
# 4         2.92       NULL     NULL        2007Li
# 5            8       NULL      4.7      2010Feng
# 6          7.8       NULL      4.7      2010Feng
# 7     7.8, 2.7       NULL 4.6, 1.5      2011Feng
# 8     8.0, 2.7       NULL 4.7, 1.6      2011Feng
# 9     8.1, 2.8       NULL 4.7, 1.6      2011Feng
# 10           4          0        0  2012Yokokawa
# 11           7        0.2        3  2012Yokokawa
# 12         5.9        0.1      4.9  2012Yokokawa
# 13        6.14          0        0    2013MacKay
# 14        6.28          0     2.92    2013MacKay
# 15        6.11          0     2.99    2013MacKay
# 16        6.17          0     1.48    2013MacKay
# 17         6.3        0.2        3    2013MacKay
# 18        6.22        0.2     3.04    2013MacKay
# 19         6.2        0.2      4.1    2013MacKay
# 20        6.21          0        0    2013MacKay
# 21        6.26       0.19     3.05    2013MacKay
# 22         6.2          0        3    2013MacKay
# 23         6.3        0.2        4    2013MacKay
# 24         6.5       0.19      3.1    2013MacKay
# 25        6.25       0.22     2.03    2013MacKay
# 26        6.08          0        0    2013MacKay
# 27           6       NULL      1.6       2014Yue
# 28        NULL       NULL      5.4       2015Jin
# 29        NULL       NULL      5.4       2015Jin
# 30    7.9, 2.8 0.10, 0.04 4.4, 1.4      2017Feng
# 31    8.0, 2.8 0.10, 0.04 4.2, 1.4      2017Feng
# 32    7.9, 2.7 0.10, 0.03 4.0, 1.3      2017Feng
# 33    8.0, 2.8 0.10, 0.04 4.1, 1.4      2017Feng
# 34    8.0, 2.8 0.10, 0.04 4.0, 1.4      2017Feng
# 35    7.9, 2.7 0.10, 0.03 3.9, 1.3      2017Feng
# 36  8.00, 2.78 0.10, 0.04 4.0, 1.3      2017Feng
# 37        NULL       NULL     NULL      2010Feng
# 38        NULL       NULL     NULL      2010Feng
# 39        NULL       NULL     NULL      2010Feng
# 40        NULL       NULL     NULL      2010Feng
# 41         1.8       NULL        3      2011Feng
# 42         3.1       NULL      0.8      2011Feng
# 43        0.58       NULL     3.75      2011Feng
# 44         2.1       NULL        2      2011Feng
# 45         4.1       NULL      0.7      2011Feng
# 46        0.51       NULL     2.86      2011Feng
# 47         1.6       NULL      4.4      2011Feng
# 48         3.4       NULL      0.8      2011Feng
# 49        0.47       NULL      5.5      2011Feng
# 50         2.3       NULL      2.2      2011Feng
# 51         3.5       NULL      0.7      2011Feng
# 52        0.66       NULL     3.14      2011Feng
# 53         1.3       NULL      7.1      2011Feng
# 54         3.7       NULL      0.5      2011Feng
# 55        0.35       NULL     14.2      2011Feng
# 56         1.9       NULL      4.9      2011Feng
# 57         4.7       NULL      0.5      2011Feng
# 58         0.4       NULL      9.8      2011Feng
# 59        NULL       NULL     NULL      2011Feng
# 60        NULL       NULL     NULL      2011Feng
# 61        NULL       NULL     NULL      2011Feng
# 62        NULL       NULL     NULL      2011Feng
# 63        NULL       NULL     NULL      2011Feng
# 64        NULL       NULL     NULL      2011Feng
# 65        NULL       NULL     NULL      2011Feng
# 66        NULL       NULL     NULL      2011Feng
# 67        NULL       NULL     NULL      2011Feng
# 68        NULL       NULL     NULL  2012Yokokawa
# 69        NULL       NULL     NULL  2012Yokokawa
# 70        NULL       NULL     NULL  2012Yokokawa
# 71        NULL       NULL     NULL  2012Yokokawa
# 72        NULL       NULL     NULL  2012Yokokawa
# 73        NULL       NULL     NULL  2012Yokokawa
# 74        NULL       NULL     NULL  2012Yokokawa
# 75        NULL       NULL     NULL  2012Yokokawa
# 76        NULL       NULL     NULL  2012Yokokawa
# 77        NULL       NULL     NULL    2013MacKay
# 78        NULL       NULL     NULL    2013MacKay
# 79        NULL       NULL     NULL    2013MacKay
# 80        NULL       NULL     NULL    2013MacKay
# 81        NULL       NULL     NULL    2013MacKay
# 82        NULL       NULL     NULL    2013MacKay
# 83        NULL       NULL     NULL    2013MacKay
# 84        NULL       NULL     NULL    2013MacKay
# 85        NULL       NULL     NULL    2013MacKay
# 86        NULL       NULL     NULL    2013MacKay
# 87        NULL       NULL     NULL    2013MacKay
# 88        NULL       NULL     NULL    2013MacKay
# 89        NULL       NULL     NULL    2013MacKay
# 90        NULL       NULL     NULL    2013MacKay
# 91        NULL       NULL     NULL    2013MacKay
# 92        NULL       NULL     NULL    2013MacKay
# 93        NULL       NULL     NULL    2013MacKay
# 94        NULL       NULL     NULL    2013MacKay
# 95        NULL       NULL     NULL    2013MacKay
# 96        NULL       NULL     NULL    2013MacKay
# 97        NULL       NULL     NULL    2013MacKay
# 98        NULL       NULL     NULL    2013MacKay
# 99        NULL       NULL     NULL    2013MacKay
# 100       NULL       NULL     NULL    2013MacKay
# 101       NULL       NULL     NULL    2013MacKay
# 102       NULL       NULL     NULL    2013MacKay
# 103       NULL       NULL     NULL    2013MacKay
# 104       NULL       NULL     NULL    2013MacKay
# 105       NULL       NULL     NULL        2016Li
# 106       NULL       NULL     NULL        2016Li
# 107       NULL       NULL     NULL        2016Li
# 108       NULL       NULL     NULL        2016Li
# 109       NULL       NULL     NULL      2017Feng
# 110       NULL       NULL     NULL      2017Feng
# 111       NULL       NULL     NULL      2017Feng
# 112       NULL       NULL     NULL      2017Feng
# 113       NULL       NULL     NULL      2017Feng
# 114       NULL       NULL     NULL      2017Feng
# 115       NULL       NULL     NULL      2017Feng
# 116       NULL       NULL     NULL    2013MacKay
# 117       NULL       NULL     NULL    2013MacKay
# 118       NULL       NULL     NULL       2014Yue
# 119       NULL       NULL     NULL       2014Yue
# 120       NULL       NULL     NULL       2014Yue
# 121       NULL       NULL     NULL       2014Yue
# 122       NULL       NULL     NULL       2014Yue
# 123       NULL       NULL     NULL       2014Yue
# 124       NULL       NULL     NULL        2015Li
# 125       NULL       NULL     NULL        2015Li
# 126       NULL       NULL     NULL        2015Li
# 127       NULL       NULL     NULL        2015Li
# 128       NULL       NULL     NULL       2016Jin
# 129       NULL       NULL     NULL       2016Jin
# 130       NULL       NULL     NULL    2017Zhixun
# 131       NULL       NULL     NULL    2017Zhixun
# 132       NULL       NULL     NULL    2017Zhixun
# 133       NULL       NULL     NULL    2017Zhixun
# 134       NULL       NULL     NULL    2017Zhixun
# 135       NULL       NULL     NULL    2017Zhixun
# 136       NULL       NULL     NULL    2017Zhixun
# 137       NULL       NULL     NULL    2017Zhixun
# 138       NULL       NULL     NULL    2017Zhixun
# 139       NULL       NULL     NULL      2011 Jin
# 140       NULL       NULL     NULL      2011 Jin
# 141       NULL       NULL     NULL      2011 Jin
# 142       NULL       NULL     NULL      2011 Jin
# 143          6        0.1        5 2004 Murakumo
# 144          6        0.1        5 2004 Murakumo
#                                                                                                                                                                                                                                                                                      Table
# 1                                                                                                                                                                                                       Table 1. Chemical composition (wt%) of _ and __ phases in TMS-75 calculated by ADP
# 
# 89           NA        NULL             NA         NA               NA
# 90           NA        NULL             NA         NA               NA
# 91           NA        NULL             NA         NA               NA
# 92           NA        NULL             NA         NA               NA
# 93           NA        NULL             NA         NA               NA
# 94           NA        NULL             NA         NA               NA
# 95           NA        NULL             NA         NA               NA
# 96           NA        NULL             NA         NA               NA
# 97           NA        NULL             NA         NA               NA
# 98           NA        NULL             NA         NA               NA
# 99           NA        NULL             NA         NA               NA
# 100          NA        NULL             NA         NA               NA
# 101          NA        NULL             NA         NA               NA
# 102          NA        NULL             NA         NA               NA
# 103          NA        NULL             NA         NA               NA
# 104          NA        NULL             NA         NA               NA
# 105          NA        NULL             NA         NA               NA
# 106          NA        NULL             NA         NA               NA
# 107          NA        NULL             NA         NA               NA
# 108          NA        NULL             NA         NA               NA
# 109          NA        NULL             NA         NA               NA
# 110          NA        NULL             NA         NA               NA
# 111          NA        NULL             NA         NA               NA
# 112          NA        NULL             NA         NA               NA
# 113          NA        NULL             NA         NA               NA
# 114          NA        NULL             NA         NA               NA
# 115          NA        NULL             NA         NA               NA
# 116          NA        NULL             NA         NA               NA
# 117          NA        NULL             NA         NA               NA
# 118          NA        NULL             NA         NA               NA
# 119          NA        NULL             NA         NA               NA
# 120          NA        NULL             NA         NA               NA
# 121          NA        NULL             NA         NA               NA
# 122          NA        NULL             NA         NA               NA
# 123          NA        NULL             NA         NA               NA
# 124          NA        NULL             NA         NA               NA
# 125          NA        NULL             NA         NA               NA
# 126          NA        NULL             NA         NA               NA
# 127          NA        NULL             NA         NA               NA
# 128        39.1        NULL             NA         NA               NA
# 129         3.7        NULL             NA         NA               NA
# 130          NA       [001]            2.3      198.1             0.82
# 131          NA       [001]            3.1      208.9             1.50
# 132          NA       [001]            1.7      205.6             1.20
# 133          NA       [011]            1.6      224.2             0.75
# 134          NA       [011]            2.2      231.1             0.80
# 135          NA       [011]            3.1      236.4             0.82
# 136          NA         111            3.6      243.5             0.68
# 137          NA         111            2.9      285.7             0.80
# 138          NA         111            1.9      254.2             0.72
# 139          NA        NULL             NA         NA               NA
# 140          NA        NULL             NA         NA               NA
# 141          NA        NULL             NA         NA               NA
# 142          NA        NULL             NA         NA               NA
# 143          NA        NULL             NA         NA               NA
# 144          NA        NULL             NA         NA               NA
#     Elongation/% Reduction of area/% tfa (h) tsa (h) tta (h)  ts/tf  tt/tf
# 1             NA                  NA      NA      NA      NA   <NA>   <NA>
# 2             NA                  NA      NA      NA      NA   <NA>   <NA>
# 3             NA                  NA      NA      NA      NA   <NA>   <NA>
# 4             NA                  NA      NA      NA      NA   <NA>   <NA>
# 5             NA                  NA      NA      NA      NA   <NA>   <NA>
# 6             NA                  NA      NA      NA      NA   <NA>   <NA>
# 7             NA                  NA      NA      NA      NA   <NA>   <NA>
# 8             NA                  NA      NA      NA      NA   <NA>   <NA>
# 9             NA                  NA      NA      NA      NA   <NA>   <NA>
# 10            NA                  NA      NA      NA      NA   <NA>   <NA>
# 11            NA                  NA      NA      NA      NA   <NA>   <NA>
# 12            NA                  NA      NA      NA      NA   <NA>   <NA>
# 115           NA                  NA      NA      NA      NA   <NA>   <NA>
# 116           NA                  NA      NA      NA      NA   <NA>   <NA>
# 117           NA                  NA      NA      NA      NA   <NA>   <NA>
# 118           NA                  NA      NA      NA      NA   <NA>   <NA>
# 119           NA                  NA      NA      NA      NA   <NA>   <NA>
# 120           NA                  NA      NA      NA      NA   <NA>   <NA>
# 121           NA                  NA      NA      NA      NA   <NA>   <NA>
# 122           NA                  NA      NA      NA      NA   <NA>   <NA>
# 123           NA                  NA      NA      NA      NA   <NA>   <NA>
# 124           NA                  NA      NA      NA      NA   <NA>   <NA>
# 125           NA                  NA      NA      NA      NA   <NA>   <NA>
# 126           NA                  NA      NA      NA      NA   <NA>   <NA>
# 127           NA                  NA      NA      NA      NA   <NA>   <NA>
# 128           NA                  NA      NA      NA      NA   <NA>   <NA>
# 129           NA                  NA      NA      NA      NA   <NA>   <NA>
# 130         0.65                 1.9      NA      NA      NA   <NA>   <NA>
# 131         0.74                 1.7      NA      NA      NA   <NA>   <NA>
# 132         0.71                 1.7      NA      NA      NA   <NA>   <NA>
# 133         1.12                 8.6      NA      NA      NA   <NA>   <NA>
# 134         1.33                 8.9      NA      NA      NA   <NA>   <NA>
# 135         1.34                 9.0      NA      NA      NA   <NA>   <NA>
# 136         0.95                 5.8      NA      NA      NA   <NA>   <NA>
# 137         1.18                 6.5      NA      NA      NA   <NA>   <NA>
# 138         1.05                 6.1      NA      NA      NA   <NA>   <NA>
# 139           NA                  NA   156.9    77.9    55.7 49.60% 35.50%
# 140           NA                  NA   211.2   105.4    75.5 49.90% 35.70%
# 141           NA                  NA    80.1    18.4    54.5 23.00% 68.00%
# 142           NA                  NA   127.1    40.0    74.2 31.50% 58.40%
# 143           NA                  NA      NA      NA      NA   <NA>   <NA>
# 144           NA                  NA      NA      NA      NA   <NA>   <NA>

# %% [markdown]
# # Query Data

# %% [markdown]
# ###  Find specific documents

# %%
Ni$find('{"W": 2.1}')
# Out:
#  Imported 1 records. Simplifying into dataframe...
#   Alloy   Region        Phase Al  Ta  W   Co  Re Cr Lattice misfit (δ), %
# 1 USTB-F1 Dendrite core γ     8.2 1.8 2.1 9.2 3  0  0.04
#   Source
# 1 2011Feng
#   Table
# 1 Table 3. Compositions in atomic percent and the associated elemental partitioning ratios (ki) of γ/γ′  phases as well as the lattice misfits (δ) estimated by the formula presented by Kablov and Petrushin [17] of the investigated alloys after thermal exposure at 1100 C for 800h.

# %%
Ni$find('{"Co": 7.0}')
# Out:
#  Imported 3 records. Simplifying into dataframe...
#   Alloy   Ni   Al        Ta       W        Co       Re       Cr       Ru
# 1 USTB-F2 Bal. 6         8        5.7      7        4.7      2.8       0
# 2 USTB-F1 Bal. 5.9, 13.6 7.8, 2.7 5.7, 1.9 7.0, 7.4 4.6, 1.5 0        NA
# 3 USTB-F2 Bal. 6.0, 13.8 8.0, 2.7 5.7, 1.9 7.0, 7.3 4.7, 1.6 2.8, 3.6 NA
#   Source
# 1 2010Feng
# 2 2011Feng
# 3 2011Feng
#   Table
# 1 Table 1. Measured compositions of two investigated alloys (mass fraction, %)
# 2 Table 1. Measured compositions of three investigated alloys (wt.%/at.%).
# 3 Table 1. Measured compositions of three investigated alloys (wt.%/at.%).

# %% [markdown]
# ### Find Documents that contain a specific element
# Find Alloys that contains Al, sorting from lowest to highest

# %%
# Ni$find('{"Al": {"$exists" : true}}')
# Ni$find('{"Al": {"$ne" : null}}')


 Ni$find(
  query = '{"Al": {"$exists" : true}}', 
    sort = '{"Al": 1}',
  limit = 5
)
# Out:
#  Imported 5 records. Simplifying into dataframe...
#   Alloy   Region                Phase Al   Ta   W    Co   Re    Cr
# 1 USTB-F1 Dendrite core         ki    0.53 0.58 1.24 1.56  3.75 0.00
# 2 USTB-F2 Interdendritic region ki    0.53 0.66 1.25 1.65  3.14 2.32
# 3 USTB-F3 Dendrite core         ki    0.53 0.35 1.29 1.57 14.20 2.32
# 4 USTB-F2 Dendrite core         ki    0.54 0.47 1.35 1.48  5.50 1.75
# 5 USTB-F1 Interdendritic region ki    0.55 0.51 1.33 1.61  2.86 0.00
#   Lattice misfit (δ), % Source
# 1  0.04                 2011Feng
# 2 -0.01                 2011Feng
# 3 -0.49                 2011Feng
# 4 -0.22                 2011Feng
# 5  0.23                 2011Feng
#   Table
# 1 Table 3. Compositions in atomic percent and the associated elemental partitioning ratios (ki) of γ/γ′  phases as well as the lattice misfits (δ) estimated by the formula presented by Kablov and Petrushin [17] of the investigated alloys after thermal exposure at 1100 C for 800h.
# 2 Table 3. Compositions in atomic percent and the associated elemental partitioning ratios (ki) of γ/γ′  phases as well as the lattice misfits (δ) estimated by the formula presented by Kablov and Petrushin [17] of the investigated alloys after thermal exposure at 1100 C for 800h.
# 3 Table 3. Compositions in atomic percent and the associated elemental partitioning ratios (ki) of γ/γ′  phases as well as the lattice misfits (δ) estimated by the formula presented by Kablov and Petrushin [17] of the investigated alloys after thermal exposure at 1100 C for 800h.
# 4 Table 3. Compositions in atomic percent and the associated elemental partitioning ratios (ki) of γ/γ′  phases as well as the lattice misfits (δ) estimated by the formula presented by Kablov and Petrushin [17] of the investigated alloys after thermal exposure at 1100 C for 800h.
# 5 Table 3. Compositions in atomic percent and the associated elemental partitioning ratios (ki) of γ/γ′  phases as well as the lattice misfits (δ) estimated by the formula presented by Kablov and Petrushin [17] of the investigated alloys after thermal exposure at 1100 C for 800h.

# %% [markdown]
# ### Find Documents that exclude a particular property / element
#
# Find Alloys that do not contain Co

# %%
 Ni$find(
  query = '{"Hf": {"$exists" : false}}', 
  limit = 5
)
# Out:
#  Imported 5 records. Simplifying into dataframe...
#   Alloy             Al        Ti   Cr       W        Ta       C     P
# 1 [001] Orientation 5.47      2.14 8.39     9.47     2.92     0.014 0.002
# 2 USTB-F2           6           NA 2.8      5.7      8           NA    NA
# 3 USTB-F5           6.1         NA 2.9      5.7      7.8         NA    NA
# 4 USTB-F1           5.9, 13.6   NA 0        5.7, 1.9 7.8, 2.7    NA    NA
# 5 USTB-F2           6.0, 13.8   NA 2.8, 3.6 5.7, 1.9 8.0, 2.7    NA    NA
#   Ni      Source
# 1 Balance 2007Li
# 2 Bal.    2010Feng
# 3 Bal.    2010Feng
# 4 Bal.    2011Feng
# 5 Bal.    2011Feng
#   Table
# 1 Table 1. Chemical composition of the alloy (wt.%)
# 2 Table 1. Measured compositions of two investigated alloys (mass fraction, %)
# 3 Table 1. Measured compositions of two investigated alloys (mass fraction, %)
# 4 Table 1. Measured compositions of three investigated alloys (wt.%/at.%).
# 5 Table 1. Measured compositions of three investigated alloys (wt.%/at.%).
#   Co       Re       Ru
# 1 NULL     NULL      NA
# 2 7        4.7      0.0
# 3 7.1      4.7      5.1
# 4 7.0, 7.4 4.6, 1.5  NA
# 5 7.0, 7.3 4.7, 1.6  NA

# %% [markdown]
# ### Find Documents according to Author / Paper

# %% [markdown]
# Find documents from the paper 2010Feng

# %%
Ni$find(
    query = '{"Source": "2010Feng"}',
    limit = 5
)
# Out:
#  Imported 5 records. Simplifying into dataframe...
#   Alloy   Ni   Al  Ta  W   Co  Re  Cr  Ru  Source
# 1 USTB-F2 Bal. 6.0 8.0 5.7 7.0 4.7 2.8 0.0 2010Feng
# 2 USTB-F5 Bal. 6.1 7.8 5.7 7.1 4.7 2.9 5.1 2010Feng
# 3 USTB-F2 NA    NA  NA  NA  NA  NA  NA  NA 2010Feng
# 4 USTB-F5 NA    NA  NA  NA  NA  NA  NA  NA 2010Feng
# 5 USTB-F2 NA    NA  NA  NA  NA  NA  NA  NA 2010Feng
#   Table
# 1 Table 1. Measured compositions of two investigated alloys (mass fraction, %)
# 2 Table 1. Measured compositions of two investigated alloys (mass fraction, %)
# 3 Table 2. Morphology, volume fraction and size of γ′ precipitates as well as width of γ channels in two investigated alloys after being aged at 1 100 °C for 8 h
# 4 Table 2. Morphology, volume fraction and size of γ′ precipitates as well as width of γ channels in two investigated alloys after being aged at 1 100 °C for 8 h
# 5 Table 2. Morphology, volume fraction and size of γ′ precipitates as well as width of γ channels in two investigated alloys after being aged at 1 100 °C for 8 h
#   y` precipitate morphology y`volume fraction/% y`size/_m y channel width/nm
# 1 NA                        NA                  NA        NA
# 2 NA                        NA                  NA        NA
# 3 Intermediate              55.1±0.8            0.37±0.12 77±22
# 4 Cuboidal                  61.0±0.7            0.28±0.09 45±13
# 5 Nearly spherical          63.5±1.0            0.55±0.10 95±38
#   Region
# 1 NA
# 2 NA
# 3 Dendrite core
# 4 Dendrite core
# 5 Interdendritic region

# %% [markdown]
# Combination of

# %%
Ni$find(
    query = '{"Source" : { "$in" : [ "2011Feng", "2010Feng", "2015Li" ] } }',
    limit = 5
    )
# Out:
#  Imported 5 records. Simplifying into dataframe...
#   Alloy   Ni   Al        Ta       W        Co       Re       Cr       Ru
# 1 USTB-F2 Bal. 6         8        5.7      7        4.7      2.8      0.0
# 2 USTB-F5 Bal. 6.1       7.8      5.7      7.1      4.7      2.9      5.1
# 3 USTB-F1 Bal. 5.9, 13.6 7.8, 2.7 5.7, 1.9 7.0, 7.4 4.6, 1.5 0         NA
# 4 USTB-F2 Bal. 6.0, 13.8 8.0, 2.7 5.7, 1.9 7.0, 7.3 4.7, 1.6 2.8, 3.6  NA
# 5 USTB-F3 Bal. 5.8, 13.3 8.1, 2.8 5.7, 1.9 7.2, 7.6 4.7, 1.6 5.7, 6.8  NA
#   Source
# 1 2010Feng
# 2 2010Feng
# 3 2011Feng
# 4 2011Feng
# 5 2011Feng
#   Table
# 1 Table 1. Measured compositions of two investigated alloys (mass fraction, %)
# 2 Table 1. Measured compositions of two investigated alloys (mass fraction, %)
# 3 Table 1. Measured compositions of three investigated alloys (wt.%/at.%).
# 4 Table 1. Measured compositions of three investigated alloys (wt.%/at.%).
# 5 Table 1. Measured compositions of three investigated alloys (wt.%/at.%).

# %% [markdown]
# ## Find Documents according to Table Name

# %%
Ni$find(
query ='{"Table": "Table 1. Analyzed compositions (wt%) of single crystal alloys"}',
    limit = 5 
)
# Out:
#  Imported 5 records. Simplifying into dataframe...
#   Alloy    Cr   Co   Mo    Re   Al   Ta   Hf  Ya (ppm wt) Ni      B      C
# 1 LDS-0010 0.00 0.00 12.02 0.00 6.08 6.14 0.0 53          balance 0.0040 0.0140
# 2 LDS-0101 0.01 9.76  7.01 2.92 6.01 6.28 0.0 70          balance 0.0045 0.0098
# 3 LDS-5051 2.35 0.00  9.01 2.99 6.03 6.11 0.0 65          balance 0.0040 0.0140
# 4 LDS-5555 2.43 4.91  9.48 1.48 6.03 6.17 0.0 46          balance 0.0032 0.0168
# 5 LDS-4583 3.90 5.00  8.10 3.00 6.00 6.30 0.2 57          balance 0.0030 0.0104
#   S (ppm wt) Source
# 1 n/a        2013MacKay
# 2 n/a        2013MacKay
# 3 2.8        2013MacKay
# 4 2.8        2013MacKay
# 5 2.8        2013MacKay
#   Table
# 1 Table 1. Analyzed compositions (wt%) of single crystal alloys
# 2 Table 1. Analyzed compositions (wt%) of single crystal alloys
# 3 Table 1. Analyzed compositions (wt%) of single crystal alloys
# 4 Table 1. Analyzed compositions (wt%) of single crystal alloys
# 5 Table 1. Analyzed compositions (wt%) of single crystal alloys

# %% [markdown]
# ## Find Documents from Keywords

# %% [markdown]
# ### Find documents from keyword "phase"  from Tables key

# %%
Ni$find(
    query = '{ "Table" : { "$regex" : "phase", "$options" : "i" }  }',
    limit = 5
)
# Out:
#  Imported 5 records. Simplifying into dataframe...
#   Alloy           Ni    Co    Cr   Mo   W    Al    Ta   Hf   Re
# 1 Standard TMS-75 59.90 12.00 3.00 2.00 6.00  6.00 6.00 0.10  5.00
# 2 y phase         52.05 17.85 5.87 3.41 6.23  2.40 1.82 0.03 10.35
# 3 y` phase        65.69  7.72 0.89 0.95 5.83  8.64 9.06 0.15  1.07
# 4 USTB-F1            NA  9.20 0.00   NA 2.10  8.20 1.80   NA  3.00
# 5 USTB-F1            NA  5.90 0.00   NA 1.70 15.40 3.10   NA  0.80
#   Source
# 1 2004 Murakumo
# 2 2004 Murakumo
# 3 2004 Murakumo
# 4 2011Feng
# 5 2011Feng
#   Table
# 1 Table 1. Chemical composition (wt%) of _ and __ phases in TMS-75 calculated by ADP
# 2 Table 1. Chemical composition (wt%) of _ and __ phases in TMS-75 calculated by ADP
# 3 Table 1. Chemical composition (wt%) of _ and __ phases in TMS-75 calculated by ADP
# 4 Table 3. Compositions in atomic percent and the associated elemental partitioning ratios (ki) of γ/γ′  phases as well as the lattice misfits (δ) estimated by the formula presented by Kablov and Petrushin [17] of the investigated alloys after thermal exposure at 1100 C for 800h.
# 5 Table 3. Compositions in atomic percent and the associated elemental partitioning ratios (ki) of γ/γ′  phases as well as the lattice misfits (δ) estimated by the formula presented by Kablov and Petrushin [17] of the investigated alloys after thermal exposure at 1100 C for 800h.
#   Region        Phase Lattice misfit (δ), %
# 1 NA            NA      NA
# 2 NA            NA      NA
# 3 NA            NA      NA
# 4 Dendrite core γ     0.04
# 5 Dendrite core γ′    0.04

# %% [markdown]
# ## Year Published Search Enter range of year published to search.

# %%
Ni$find('{ "Source" : { "$regex" : "2004", "$options" : "i" }  }')
# Out:
#  Imported 5 records. Simplifying into dataframe...
#   Alloy           Ni    Co    Cr   Mo   W    Al   Ta   Hf   Re    Source
# 1 Standard TMS-75 59.90 12.00 3.00 2.00 6.00 6.00 6.00 0.10  5.00 2004 Murakumo
# 2 y phase         52.05 17.85 5.87 3.41 6.23 2.40 1.82 0.03 10.35 2004 Murakumo
# 3 y` phase        65.69  7.72 0.89 0.95 5.83 8.64 9.06 0.15  1.07 2004 Murakumo
# 4 TMS-2004        59.90 12.00 3.00 2.00 6.00 6.00 6.00 0.10  5.00 2004 Murakumo
# 5 TMS-2004        59.90 12.00 3.00 2.00 6.00 6.00 6.00 0.10  5.00 2004 Murakumo
#   Table
# 1 Table 1. Chemical composition (wt%) of _ and __ phases in TMS-75 calculated by ADP
# 2 Table 1. Chemical composition (wt%) of _ and __ phases in TMS-75 calculated by ADP
# 3 Table 1. Chemical composition (wt%) of _ and __ phases in TMS-75 calculated by ADP
# 4 Table 1. Chemical composition (wt%) of y and y`phases in TMS-75 calculated by ADP
# 5 Table 1. Chemical composition (wt%) of y and y`phases in TMS-75 calculated by ADP

# %% [markdown]
# ## Author Search Enter author names

# %%
Ni$find('{ "Source" : { "$regex" : "Murakumo", "$options" : "i" }  }')
# Out:
#  Imported 5 records. Simplifying into dataframe...
#   Alloy           Ni    Co    Cr   Mo   W    Al   Ta   Hf   Re    Source
# 1 Standard TMS-75 59.90 12.00 3.00 2.00 6.00 6.00 6.00 0.10  5.00 2004 Murakumo
# 2 y phase         52.05 17.85 5.87 3.41 6.23 2.40 1.82 0.03 10.35 2004 Murakumo
# 3 y` phase        65.69  7.72 0.89 0.95 5.83 8.64 9.06 0.15  1.07 2004 Murakumo
# 4 TMS-2004        59.90 12.00 3.00 2.00 6.00 6.00 6.00 0.10  5.00 2004 Murakumo
# 5 TMS-2004        59.90 12.00 3.00 2.00 6.00 6.00 6.00 0.10  5.00 2004 Murakumo
#   Table
# 1 Table 1. Chemical composition (wt%) of _ and __ phases in TMS-75 calculated by ADP
# 2 Table 1. Chemical composition (wt%) of _ and __ phases in TMS-75 calculated by ADP
# 3 Table 1. Chemical composition (wt%) of _ and __ phases in TMS-75 calculated by ADP
# 4 Table 1. Chemical composition (wt%) of y and y`phases in TMS-75 calculated by ADP
# 5 Table 1. Chemical composition (wt%) of y and y`phases in TMS-75 calculated by ADP

# %% [markdown]
# ## Aggregate Pipelines

# %% [markdown]
# #### Group by Tables and Count

# %%
 Ni$aggregate('[{ "$group" : 
                      { "_id" : "$Table", 
                        "number_records" : { "$sum" : 1}
                      }
                  }]')


# names(tables) <- c("Tables", "Count")
# print(tables )
# Out:
#  Imported 28 records. Simplifying into dataframe...
#    _id
# 1  Table 2 Chemical composition of ReneN4, ReneN5, and TMS-138.
# 2  Table 2. Stress-rupture properties of IC21 alloy after thermal exposure at 1100 °C under the test condition of1100 °C/137 MPa.
# 3  Table 1. Chemical composition of DD6 single crystal superalloy (in wt%).
# 4  Table 3. The time spans of secondary and tertiary stages and their percentage in the whole creep rupture life of each creep curve under both conditions.
# 5  Table 1. Measured compositions of the experimental alloys (wt%at%).
# 6  Table 2. Microstructure features, creep rupture and interrupted lives during creep process at 950 °C and 400 MPa in experimental alloys.
# 7  Table 3. The experimental results of DD6 Ni-based single crystal superalloy at 1100 °C.
# 8  Table 1. Stress rupture properties of the SC superalloy specimens with three orientations: t characterizes the rupture lifetime and marks the rupture elongation
# 9  Table 2. Morphology, volume fraction and size of γ′ precipitates as well as width of γ channels in two investigated alloys after being aged at 1 100 °C for 8 h
# 10 Table 1. Nominal chemical compositions (wt.%) of the experimental superalloys investigated.
# 11 Table 3 Volume fractions of γ′ phase, lattice misfits and creep rupture lives of ReneN4, ReneN5, and TMS-138.
# 12 Table 5. Linear termination densities after 1% creep stain and time to 1% creep strain at 1100 °C/130 MPa.
# 13 Table 1. Measured compositions of the experimental alloys (wt%at%)
# 14 Table 2. Measured microstructural parameters.
# 15 Table 4. Normalized microstructural parameter statistics.
# 16 Table 1. Measured compositions of three investigated alloys (wt.%/at.%).
# 17 Table 3. Creep rupture lives for single crystal alloys.
# 18 Table 3. The experimental results of DD6 Ni-based single crystal at 980 °C/400 MPa.
# 19 Table 3. Compositions in atomic percent and the associated elemental partitioning ratios (ki) of γ/γ′  phases as well as the lattice misfits (δ) estimated by the formula presented by Kablov and Petrushin [17] of the investigated alloys after thermal exposure at 1100 C for 800h.
# 20 Table 1. Chemical composition of the alloy (wt.%)
# 21 Table 1. Chemical composition (wt%) of y and y`phases in TMS-75 calculated by ADP
# 22 Table 4. Stress–rupture properties of the investigated alloys at 1100 °C/140 MPa.
# 23 Creep properties of some single crystal superalloys under different test conditions
# 24 Table 3. Lattice misfit at ambient temperature and dislocation spacing of Alloy-1 and Alloy-2.
# 25 Table 1. Analyzed compositions (wt%) of single crystal alloys
# 26 Table 1. Chemical composition (wt%) of _ and __ phases in TMS-75 calculated by ADP
# 27 Table 2. Stress-rupture lives of the two alloys under the test conditions of 850 °C/500 MPa and 1100 °C/130 MPa.
# 28 Table 1. Measured compositions of two investigated alloys (mass fraction, %)
#    number_records
# 1   3
# 2   3
# 3   1
# 4   4
# 5   6
# 6   7
# 7   6
# 8   2
# 9   4
# 10  2
# 11  9
# 12  3
# 13  1
# 14 14
# 15  2
# 16  3
# 17 14
# 18  9
# 19 18
# 20  1
# 21  2
# 22  6
# 23  1
# 24  2
# 25 14
# 26  3
# 27  2
# 28  2

# %% [markdown]
# #### Group by Paper and count

# %%
  SourceRecords <-  Ni$aggregate('[{ "$group" : 
                      { "_id" : "$Source", 
                        "count" : { "$sum" : 1},
                        "$sort": {"Source":1}
                      }
                  }]')


# assign some names
names(SourceRecords) <- c("Author", "Count")
print(SourceRecords )
# Out:
# Error: The field '$sort' must be an accumulator object
# Traceback:
#
# 1. Ni$aggregate("[{ \"$group\" : \n                      { \"_id\" : \"$Source\", \n                        \"count\" : { \"$sum\" : 1},\n                        \"$sort\": {\"Source\":1}\n                      }\n                  }]")
# 2. mongo_stream_in(cur, handler = handler, pagesize = pagesize,
#  .     verbose = verbose)
# 3. mongo_cursor_next_page(cur, pagesize)

# %% [markdown]
# m$aggregatedt(pipeline = '[{"$match" : { "hp" : { "$gte" : 100} } }, {"$project" : {"test" : "$mpg" }}, {"$sort" : {"test" : 1} } ]')

# %%
  SourceRecords1 <-  Ni$aggregate('[{ "$group" : 
                      { "_id" : "$Co", 
                        "count" : {"$sum": 1},
                        "sort"

                      }
                  }]')

#   '[{"$group":{"_id":"$carrier", "count": {"$sum":1}, "average":{"$avg":"$distance"}}}]',
#   options = '{"allowDiskUse":true}'
# assign some names
names(SourceRecords1) <- c("Author", "Count")
print(SourceRecords1 )
# Out:
#  Imported 44 records. Simplifying into dataframe...
#        Author Count
# 1         8.2     1
# 2          11     1
# 3           5     1
# 4        1.57     1
# 5         8.1     1
# 6    7.1, 7.4     1
# 7        1.69     1
# 8         9.9     1
# 9        1.65     1
# 10        5.1     1
# 11       9.76     2
# 12 14.5, 15.5     1
# 13   6.9, 7.2     1
# 14          7     1
# 15        5.8     1
# 16         10     2
# 17          8     2
# 18 15.0, 15.9     1
# 19       7.72     1
# 20       9.97     1
# 21   6.9, 7.4     2
# 22 14.4, 15.2     1
# 23        8.5     1
# 24       4.98     1
# 25   7.2, 7.6     1
# 26   7.0, 7.4     1
# 27        7.9     1
# 28       NULL    89
# 29        7.1     1
# 30          0     3
# 31        4.8     2
# 32         12     5
# 33       1.61     1
# 34       1.48     1
# 35        9.4     1
# 36          6     1
# 37        5.9     1
# 38        6.2     1
# 39      17.85     1
# 40       4.91     1
# 41        9.2     2
# 42       1.56     1
# 43   7.0, 7.3     1
# 44       9.99     1

# %% [markdown]
# ### Keyword Search Enter

# %% [markdown]
# ## Find Documents in Tables by Keywords

# %% [markdown]
# ## Find Queries with Specific Element Composition ranges

# %%
# Ni$find('{"W": {"$lt" : 5}}')


 Ni$find(
  query = '{"W": {"$lt" : 5}}', 
  limit = 5
)
# Out:
#  Imported 5 records. Simplifying into dataframe...
#   Alloy   Region                Phase Al    Ta   W    Co   Re   Cr
# 1 USTB-F1 Dendrite core         γ      8.20 1.80 2.10 9.20 3.00 0
# 2 USTB-F1 Dendrite core         γ′    15.40 3.10 1.70 5.90 0.80 0
# 3 USTB-F1 Dendrite core         ki     0.53 0.58 1.24 1.56 3.75 0
# 4 USTB-F1 Interdendritic region γ      9.20 2.10 2.00 8.20 2.00 0
# 5 USTB-F1 Interdendritic region γ′    16.60 4.10 1.50 5.10 0.70 0
#   Lattice misfit (δ), % Source
# 1 0.04                  2011Feng
# 2 0.04                  2011Feng
# 3 0.04                  2011Feng
# 4 0.23                  2011Feng
# 5 0.23                  2011Feng
#   Table
# 1 Table 3. Compositions in atomic percent and the associated elemental partitioning ratios (ki) of γ/γ′  phases as well as the lattice misfits (δ) estimated by the formula presented by Kablov and Petrushin [17] of the investigated alloys after thermal exposure at 1100 C for 800h.
# 2 Table 3. Compositions in atomic percent and the associated elemental partitioning ratios (ki) of γ/γ′  phases as well as the lattice misfits (δ) estimated by the formula presented by Kablov and Petrushin [17] of the investigated alloys after thermal exposure at 1100 C for 800h.
# 3 Table 3. Compositions in atomic percent and the associated elemental partitioning ratios (ki) of γ/γ′  phases as well as the lattice misfits (δ) estimated by the formula presented by Kablov and Petrushin [17] of the investigated alloys after thermal exposure at 1100 C for 800h.
# 4 Table 3. Compositions in atomic percent and the associated elemental partitioning ratios (ki) of γ/γ′  phases as well as the lattice misfits (δ) estimated by the formula presented by Kablov and Petrushin [17] of the investigated alloys after thermal exposure at 1100 C for 800h.
# 5 Table 3. Compositions in atomic percent and the associated elemental partitioning ratios (ki) of γ/γ′  phases as well as the lattice misfits (δ) estimated by the formula presented by Kablov and Petrushin [17] of the investigated alloys after thermal exposure at 1100 C for 800h.

# %%
# Ni$find('{"W": {"$gt" : 5}}')
 Ni$find(
  query = '{"W": {"$gt" : 5}}', 
  limit = 5
)
# Out:
#  Imported 5 records. Simplifying into dataframe...
#   Alloy             Ni      Co    Cr   Mo   W    Al   Ta   Hf   Re
# 1 Standard TMS-75   59.9    12.00 3.00 2.00 6.00 6.00 6.00 0.10  5.00
# 2 y phase           52.05   17.85 5.87 3.41 6.23 2.40 1.82 0.03 10.35
# 3 y` phase          65.69    7.72 0.89 0.95 5.83 8.64 9.06 0.15  1.07
# 4 [001] Orientation Balance    NA 8.39   NA 9.47 5.47 2.92   NA    NA
# 5 USTB-F2           Bal.     7.00 2.80   NA 5.70 6.00 8.00   NA  4.70
#   Source
# 1 2004 Murakumo
# 2 2004 Murakumo
# 3 2004 Murakumo
# 4 2007Li
# 5 2010Feng
#   Table
# 1 Table 1. Chemical composition (wt%) of _ and __ phases in TMS-75 calculated by ADP
# 2 Table 1. Chemical composition (wt%) of _ and __ phases in TMS-75 calculated by ADP
# 3 Table 1. Chemical composition (wt%) of _ and __ phases in TMS-75 calculated by ADP
# 4 Table 1. Chemical composition of the alloy (wt.%)
# 5 Table 1. Measured compositions of two investigated alloys (mass fraction, %)
#   Ti   C     P     Ru
# 1   NA    NA    NA NA
# 2   NA    NA    NA NA
# 3   NA    NA    NA NA
# 4 2.14 0.014 0.002 NA
# 5   NA    NA    NA  0

# %% [markdown]
# ## Combining Queries

# %% [markdown]
# ### Required Elements, Display Alloys  which have the following Elements
# Ni, Co, Cr, Mo, W, Al, Ta

# %%
Ni$find(
  query = '{"Ni" : { "$exists" : true }, "Co" : { "$exists" : true }, "Cr" : { "$exists" : true }, "Mo" : { "$exists" : true }, "W" : { "$exists" : true }, "Al" : { "$exists" : true }, "Ta" : { "$exists" : true }}', 
  fields = '{"Alloy" : true, "Ni" : true, "Co" : true,"Cr":true, "Mo": true, "W" : true, "Al": true, "Ta": true, "Source": true, "Table": true}',
  limit = 5
)
# Out:
#  Imported 5 records. Simplifying into dataframe...
#   _id                      Alloy           Ni    Co    Cr   Mo   W    Al   Ta
# 1 5f7c7c1e2e296d8251dc61e7 Standard TMS-75 59.9  12.00 3.00 2.00 6.00 6.00 6.00
# 2 5f7c7c352e296d8251dca085 y phase         52.05 17.85 5.87 3.41 6.23 2.40 1.82
# 3 5f7c7c472e296d8251dce044 y` phase        65.69  7.72 0.89 0.95 5.83 8.64 9.06
# 4 5f7c84ba2e296d8251f7b399 ReneN4          bal    8.00 9.00 2.00 6.00 3.70 4.00
# 5 5f7c85222e296d8251f8ea89 ReneN5          bal    8.00 7.00 2.00 5.00 6.20 7.00
#   Source
# 1 2004 Murakumo
# 2 2004 Murakumo
# 3 2004 Murakumo
# 4 2012Yokokawa
# 5 2012Yokokawa
#   Table
# 1 Table 1. Chemical composition (wt%) of _ and __ phases in TMS-75 calculated by ADP
# 2 Table 1. Chemical composition (wt%) of _ and __ phases in TMS-75 calculated by ADP
# 3 Table 1. Chemical composition (wt%) of _ and __ phases in TMS-75 calculated by ADP
# 4 Table 2 Chemical composition of ReneN4, ReneN5, and TMS-138.
# 5 Table 2 Chemical composition of ReneN4, ReneN5, and TMS-138.

# %% [markdown]
# ## Optional Elements, display Alloys which have either of the following elements

# %% [markdown]
# Al and Hf

# %%
 Ni$find(
  query = '{"$or":[ {"Al" : { "$exists" : true }}, {"Hf" : { "$exists" : true }} ] }', 
  fields = '{"Alloy" : true, "Al" : true, "Hf": true}',
  limit = 5
)
# Out:
#  Imported 5 records. Simplifying into dataframe...
#   _id                      Alloy             Al   Hf
# 1 5f7c7c1e2e296d8251dc61e7 Standard TMS-75   6.00 0.10
# 2 5f7c7c352e296d8251dca085 y phase           2.40 0.03
# 3 5f7c7c472e296d8251dce044 y` phase          8.64 0.15
# 4 5f7c7c592e296d8251dd2393 [001] Orientation 5.47   NA
# 5 5f7c7c692e296d8251dd5702 USTB-F2           6.00   NA

# %% [markdown]
# ## Excluded Compounds, find alloys that do not contain the following Elements

# %% [markdown]
# Co, Cr and Mo

# %%
Ni$find(
  query = '{"Co" : { "$exists" : false }, "Cr" : { "$exists" : false}, "Mo" : { "$exists" : false } }', 
  fields = '{"Alloy" : true, "Ni" : true, "Co" : true,"Cr":true, "Mo": true, "W" : true, "Al": true, "Ta": true }',
  limit = 5
)
# Out:
#  Imported 5 records. Simplifying into dataframe...
#   _id                      Alloy
# 1 5f7c87902e296d8251fbb8a4 USTB-F2
# 2 5f7c879d2e296d8251fbc0eb USTB-F5
# 3 5f7c87aa2e296d8251fbcacf USTB-F2
# 4 5f7c88332e296d8251fc2e28 USTB-F5
# 5 5f7c89bd2e296d8251fd95a3 USTB-F1

# %% [markdown]
# ## Query Alloy Composition

# %%
Ni$find('{"$or": [ {"Ni" : "bal"}, {"Mo" : 2.0}  ]}')
# Out:
#  Imported 6 records. Simplifying into dataframe...
#   Alloy           Ni   Co   Cr  Mo  W   Al  Ta  Hf  Re  Source
# 1 Standard TMS-75 59.9 12.0 3.0 2.0 6.0 6.0 6.0 0.1 5   2004 Murakumo
# 2 ReneN4          bal   8.0 9.0 2.0 6.0 3.7 4.0 -   -   2012Yokokawa
# 3 ReneN5          bal   8.0 7.0 2.0 5.0 6.2 7.0 0.2 3   2012Yokokawa
# 4 TMS-138         bal   5.8 2.9 2.9 5.9 5.9 5.9 0.1 4.9 2012Yokokawa
# 5 TMS-2004        59.9 12.0 3.0 2.0 6.0 6.0 6.0 20  5   2004 Murakumo
# 6 TMS-2004        59.9 12.0 3.0 2.0 6.0 6.0 6.0 0.1 5   2004 Murakumo
#   Table
# 1 Table 1. Chemical composition (wt%) of _ and __ phases in TMS-75 calculated by ADP
# 2 Table 2 Chemical composition of ReneN4, ReneN5, and TMS-138.
# 3 Table 2 Chemical composition of ReneN4, ReneN5, and TMS-138.
# 4 Table 2 Chemical composition of ReneN4, ReneN5, and TMS-138.
# 5 Table 1. Chemical composition (wt%) of y and y`phases in TMS-75 calculated by ADP
# 6 Table 1. Chemical composition (wt%) of y and y`phases in TMS-75 calculated by ADP
#   Ti  Nb  Ru Temp stress Misfit Vf Author
# 1 NA  NA  NA  NA   NA       NA  NA NA
# 2 4.2 0.5 -  900  392    -0.23  57 NA
# 3 -   -   -  900  392    -0.29  74 NA
# 4 -   -   2  900  392    -0.21  64 NA
# 5 NA  NA  NA  NA   NA       NA  NA Murakumo
# 6 NA  NA  NA  NA   NA       NA  NA NA

# %% [markdown]
# ## Manipulate data

# %% [markdown]
# ## Insert a document into the collection

# %%
Ni$insert(' {
      "Alloy": "TMS-2004",
      "Ni": 59.9,
      "Co": 12,
      "Cr": 3,
      "Mo": 2,
      "W": 6,
      "Al": 6,
      "Ta": 6,
      "Hf": 0.1,
      "Re": 5,
      "Source": "2004 Murakumo",
      "Table": "Table 1. Chemical composition (wt%) of y and y`phases in TMS-75 calculated by ADP"
    }')

Ni$find('{"Alloy": "TMS-2004"}')
# Out:
# List of 6
#  $ nInserted  : int 1
#  $ nMatched   : int 0
#  $ nModified  : int 0
#  $ nRemoved   : int 0
#  $ nUpserted  : int 0
#  $ writeErrors: list()
#  Imported 3 records. Simplifying into dataframe...
#   Alloy    Ni   Co Cr Mo W Al Ta Hf   Re Source
# 1 TMS-2004 59.9 12 3  2  6 6  6  20.0 5  2004 Murakumo
# 2 TMS-2004 59.9 12 3  2  6 6  6   0.1 5  2004 Murakumo
# 3 TMS-2004 59.9 12 3  2  6 6  6   0.1 5  2004 Murakumo
#   Table
# 1 Table 1. Chemical composition (wt%) of y and y`phases in TMS-75 calculated by ADP
# 2 Table 1. Chemical composition (wt%) of y and y`phases in TMS-75 calculated by ADP
# 3 Table 1. Chemical composition (wt%) of y and y`phases in TMS-75 calculated by ADP
#   Author
# 1 Murakumo
# 2 NA
# 3 NA

# %% [markdown]
# ## Check the document count after adding new document

# %%
Ni$count('[]')
# Out:
# [1] 144

# %% [markdown]
# ## Update and  Upsert a record
# The update method has the following arguments
# upsert=TRUE : Creates a new key and value pair if the set pairs are not available
# \b
# multiple = TRUE: To update multiple documents, use the multi option in the update() method.

# %%
Ni$update('{"Alloy":"TMS-2004"}', '{"$set":{"Hf":  20}}')
# Out:
# List of 3
#  $ modifiedCount: int 0
#  $ matchedCount : int 1
#  $ upsertedCount: int 0

# %%
Ni$update('{"Alloy":"TMS-2004"}', '{"$set":{"Author":  "Murakumo"}}', upsert=TRUE)
# Out:
# List of 3
#  $ modifiedCount: int 0
#  $ matchedCount : int 1
#  $ upsertedCount: int 0

# %%
Ni$find('{"Alloy": "TMS-2004"}')
# Out:
#  Imported 3 records. Simplifying into dataframe...
#   Alloy    Ni   Co Cr Mo W Al Ta Hf   Re Source
# 1 TMS-2004 59.9 12 3  2  6 6  6  20.0 5  2004 Murakumo
# 2 TMS-2004 59.9 12 3  2  6 6  6   0.1 5  2004 Murakumo
# 3 TMS-2004 59.9 12 3  2  6 6  6   0.1 5  2004 Murakumo
#   Table
# 1 Table 1. Chemical composition (wt%) of y and y`phases in TMS-75 calculated by ADP
# 2 Table 1. Chemical composition (wt%) of y and y`phases in TMS-75 calculated by ADP
# 3 Table 1. Chemical composition (wt%) of y and y`phases in TMS-75 calculated by ADP
#   Author
# 1 Murakumo
# 2 NA
# 3 NA

# %%
subjects$update('{"name":"jerry"}', '{"$set":{"age": 31}}')
# Out:
# Error in eval(expr, envir, enclos): object 'subjects' not found
# Traceback:

# %% [markdown]
# ## Remove the Document from the collection
# just_one = TRUE argument indicates removal of just one record if multiple records are found

# %%
Ni$remove('{"Alloy": "TMS-2004"}', just_one=TRUE)
Ni$count('[]')
# Out:
# [1] 144

# %% [markdown]
# ## Import and Export JSON

# %%
# Ni$export(stdout())

# %%
Ni$export(file("dump.json"))
# Out:
# Done! Exported a total of 144 lines.

# %%
 test1 <- mongo(collection = "mre", db = "Ni-Alloys", 
               url = url_path, 
               verbose = TRUE)

# %%
test1$drop()
test1$count()
# Out:
# [1] 0

# %%
test1$import(file("dump.json"))
# Out:
# Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”Warning message:
# “[WARNING] invalid document for insert: keys cannot contain ".": "Specimen no."”
# Error: invalid document for insert: keys cannot contain ".": "Specimen no."
# Traceback:
#
# 1. test1$import(file("dump.json"))
# 2. mongo_import(col, con, verbose = verbose)
# 3. mongo_collection_insert_page(col, json)

# %%
install.packages("jsonlite", repos="http://cran.r-project.org")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(jsonlite)

# %%
Ni$export(file("flights.bson"), bson = TRUE)
# Out:
# Done! Exported a total of 144 lines.

# %%
# $drop()
# test1$import(file("flights.bson"), bson = TRUE)

# %%
import$import(file("flight.bson"))
# <!-- dmd$count() -->
# Out:
# Warning message in open.connection(con, "r"):
# “cannot open file 'flight.bson': No such file or directory”
# Error in open.connection(con, "r"): cannot open the connection
# Traceback:
#
# 1. import$import(file("flight.bson"))
# 2. mongo_import(col, con, verbose = verbose)
# 3. open(con, "r")
# 4. open.connection(con, "r")

# %%
mre$drop()
# Out:
# Error in eval(expr, envir, enclos): object 'mre' not found
# Traceback:

# %%
Ni$export(stdout())
# Out:
# { "_id" : { "$oid" : "5f7c7c1e2e296d8251dc61e7" }, "Alloy" : "Standard TMS-75", "Ni" : 59.899999999999998579, "Co" : 12, "Cr" : 3, "Mo" : 2, "W" : 6, "Al" : 6, "Ta" : 6, "Hf" : 0.10000000000000000555, "Re" : 5, "Source" : "2004 Murakumo", "Table" : "Table 1. Chemical composition (wt%) of _ and __ phases in TMS-75 calculated by ADP" }
# { "_id" : { "$oid" : "5f7c7c352e296d8251dca085" }, "Alloy" : "y phase", "Ni" : 52.049999999999997158, "Co" : 17.850000000000001421, "Cr" : 5.8700000000000001066, "Mo" : 3.4100000000000001421, "W" : 6.2300000000000004263, "Al" : 2.3999999999999999112, "Ta" : 1.8200000000000000622, "Hf" : 0.02999999999999999889, "Re" : 10.349999999999999645, "Source" : "2004 Murakumo", "Table" : "Table 1. Chemical composition (wt%) of _ and __ phases in TMS-75 calculated by ADP" }
# { "_id" : { "$oid" : "5f7c7c472e296d8251dce044" }, "Alloy" : "y` phase", "Ni" : 65.689999999999997726, "Co" : 7.7199999999999997513, "Cr" : 0.89000000000000001332, "Mo" : 0.94999999999999995559, "W" : 5.8300000000000000711, "Al" : 8.6400000000000005684, "Ta" : 9.0600000000000004974, "Hf" : 0.14999999999999999445, "Re" : 1.0700000000000000622, "Source" : "2004 Murakumo", "Table" : "Table 1. Chemical composition (wt%) of _ and __ phases in TMS-75 calculated by ADP" }
# { "_id" : { "$oid" : "5f7c7c592e296d8251dd2393" }, "Alloy" : "[001] Orientation", "Al" : 5.4699999999999997513, "Ti" : 2.1400000000000001243, "Cr" : 8.3900000000000005684, "W" : 9.4700000000000006395, "Ta" : 2.9199999999999999289, "C" : 0.014000000000000000291, "P" : 0.0020000000000000000416, "Ni" : "Balance", "Source" : "2007Li", "Table" : "Table 1. Chemical composition of the alloy (wt.%)" }
# { "_id" : { "$oid" : "5f7c7c692e296d8251dd5702" }, "Alloy" : "USTB-F2", "Ni" : "Bal.", "Al" : 6, "Ta" : 8, "W" : 5.7000000000000001776, "Co" : 7, "Re" : 4.7000000000000001776, "Cr" : 2.7999999999999998224, "Ru" : 0, "Source" : "2010Feng", "Table" : "Table 1. Measured compositions of two investigated alloys (mass fraction, %)" }
# { "_id" : { "$oid" : "5f7c7c7d2e296d8251dd934c" }, "Alloy" : "USTB-F5", "Ni" : "Bal.", "Al" : 6.0999999999999996447, "Ta" : 7.7999999999999998224, "W" : 5.7000000000000001776, "Co" : 7.0999999999999996447, "Re" : 4.7000000000000001776, "Cr" : 2.8999999999999999112, "Ru" : 5.0999999999999996447, "Source" : "2010Feng", "Table" : "Table 1. Measured compositions of two investigated alloys (mass fraction, %)" }
"Source" : "2011Feng", "Table" : "Table 3. Compositions in atomic percent and the associated elemental partitioning ratios (ki) of γ/γ′  phases as well as the lattice misfits (δ) estimated by the formula presented by Kablov and Petrushin [17] of the investigated alloys after thermal exposure at 1100 C for 800h." }
# { "_id" : { "$oid" : "5f7c89a52e296d8251fd860c" }, "Alloy" : "USTB-F3", "Region" : "Interdendritic region", "Phase" : "ki", "Al" : 0.55000000000000004441, "Ta" : 0.4000000000000000222, "W" : 1.25, "Co" : 1.6899999999999999467, "Re" : 9.8000000000000007105, "Cr" : 2.2700000000000000178, "Lattice misfit (δ), %" : -0.17999999999999999334, "Source" : "2011Feng", "Table" : "Table 3. Compositions in atomic percent and the associated elemental partitioning ratios (ki) of γ/γ′  phases as well as the lattice misfits (δ) estimated by the formula presented by Kablov and Petrushin [17] of the investigated alloys after thermal exposure at 1100 C for 800h." }
# { "_id" : { "$oid" : "5f7c89bd2e296d8251fd95a3" }, "Alloy" : "USTB-F1", "Specimen no." : "1-1", "Stress-rupture life (h)" : 33.100000000000001421, "Average stress-rupture life (h)" : "29.5 ± 5.2", "Elongation (δ), %" : 34.299999999999997158, "Area reduction (Ψ), %" : 41.399999999999998579, "Source" : "2011Feng", "Table" : "Table 4. Stress–rupture properties of the investigated alloys at 1100 °C/140 MPa." }
# { "_id" : { "$oid" : "5f7c8a3f2e296d8251fdf8e5" }, "Alloy" : "USTB-F1", "Specimen no." : "1-2", "Stress-rupture life (h)" : 25.800000000000000711, "Average stress-rupture life (h)" : "29.5 ± 5.2", "Elongation (δ), %" : 44, "Area reduction (Ψ), %" : 40.899999999999998579, "Source" : "2011Feng", "Table" : "Table 4. Stress–rupture properties of the investigated alloys at 1100 °C/140 MPa." }
# { "_id" : { "$oid" : "5f7c8a4d2e296d8251fe025b" }, "Alloy" : "USTB-F2", "Specimen no." : "2-1", "Stress-rupture life (h)" : 69.200000000000002842, "Average stress-rupture life (h)" : "73.0 ± 5.4", "Elongation (δ), %" : 42.799999999999997158, "Area reduction (Ψ), %" : 57.5, "Source" : "2011Feng", "Table" : "Table 4. Stress–rupture properties of the investigated alloys at 1100 °C/140 MPa." }
# { "_id" : { "$oid" : "5f7c8a592e296d8251fe0b9b" }, "Alloy" : "USTB-F2", "Specimen no." : "2-2", "Stress-rupture life (h)" : 76.799999999999997158, "Average stress-rupture life (h)" : "73.0 ± 5.4", "Elongation (δ), %" : 49.600000000000001421, "Area reduction (Ψ), %" : 51.799999999999997158, "Source" : "2011Feng", "Table" : "Table 4. Stress–rupture properties of the investigated alloys at 1100 °C/140 MPa." }
# { "_id" : { "$oid" : "5f7c8a632e296d8251fe12ae" }, "Alloy" : "USTB-F3", "Specimen no." : "3-1", "Stress-rupture life (h)" : 131.09999999999999432, "Average stress-rupture life (h)" : "137.6 ± 9.1", "Elongation (δ), %" : 31.600000000000001421, "Area reduction (Ψ), %" : 40.600000000000001421, "Source" : "2011Feng", "Table" : "Table 4. Stress–rupture properties of the investigated alloys at 1100 °C/140 MPa." }
# { "_id" : { "$oid" : "5f7c8a6e2e296d8251fe1976" }, "Alloy" : "USTB-F3", "Specimen no." : "3-2", "Stress-rupture life (h)" : 144, "Average stress-rupture life (h)" : "137.6 ± 9.1", "Elongation (δ), %" : 32.799999999999997158, "Area reduction (Ψ), %" : 52.100000000000001421, "Source" : "2011Feng", "Table" : "Table 4. Stress–rupture properties of the investigated alloys at 1100 °C/140 MPa." }
# { "_id" : { "$oid" : "5f7c8a792e296d8251fe20b3" }, "Alloy" : "USTB-F1", "Dendrite core" : "–a", "Interdendritic region" : "6.18 ± 0.25", "Time to 1% creep strain (h)" : 9, "Source" : "2011Feng", "Table" : "Table 5. Linear termination densities after 1% creep stain and time to 1% creep strain at 1100 °C/130 MPa." }
# { "_id" : { "$oid" : "5f7c8a842e296d8251fe285e" }, "Alloy" : "USTB-F2", "Dendrite core" : "3.13 ± 0.33", "Interdendritic region" : "–", "Time to 1% creep strain (h)" : 39, "Source" : "2011Feng", "Table" : "Table 5. Linear termination densities after 1% creep stain and time to 1% creep strain at 1100 °C/130 MPa." }
# { "_id" : { "$oid" : "5f7c8a972e296d8251fe37db" }, "Alloy" : "USTB-F3", "Dendrite core" : "1.51 ± 0.26", "Interdendritic region" : "1.83 ± 0.16", "Time to 1% creep strain (h)" : 80, "Source" : "2011Feng", "Table" : "Table 5. Linear termination densities after 1% creep stain and time to 1% creep strain at 1100 °C/130 MPa." }
# { "_id" : { "$oid" : "5f7c8b5c2e296d8251fee1f7" }, "Alloy" : "ReneN4", "Vf (%)" : 57, "Misfit (%)" : -0.23000000000000000999, "Creep rupture life(h) Obs." : 223, "Creep rupture life(h) Calc." : 298, "Temp/P" : "900°C / 392MPa", "Source" : "2012Yokokawa", "Table" : "Table 3 Volume fractions of γ′ phase, lattice misfits and creep rupture lives of ReneN4, ReneN5, and TMS-138." }
# { "_id" : { "$oid" : "5f7c
"Source" : "2013MacKay", "Table" : "Table 3. Creep rupture lives for single crystal alloys." }
# { "_id" : { "$oid" : "5f7c8da42e296d82510076e2" }, "Alloy" : "LDS-1501", "Life (h) at 982 C/ 241 MPa" : "231.6, 303.6, mean=267.6", "Life (h) at 982 C/ 207 MPa" : 729.25, "Life (h) at 1093 C/ 124 MPa" : "391.65, 422.85, 484.2, 542.8, mean=460.38", "Life (h) at 1093 C/ 110 MPa" : "984.35, 1022.5, mean=1003.4", "Source" : "2013MacKay", "Table" : "Table 3. Creep rupture lives for single crystal alloys." }
# { "_id" : { "$oid" : "5f7c94762e296d82510556b5" }, "Alloy" : "LDS-1101", "Life (h) at 982 C/ 241 MPa" : "236.85, 255.35, 304.2, mean=265.47", "Life (h) at 982 C/ 207 MPa" : "938.3, 832.8, mean=885.55", "Life (h) at 1093 C/ 124 MPa" : "259.25, 325.5, 342.95, mean=309.23", "Life (h) at 1093 C/ 110 MPa" : "630.95, 632.8, mean=631.88", "Source" : "2013MacKay", "Table" : "Table 3. Creep rupture lives for single crystal alloys." }
# Exported 100 lines...{ "_id" : { "$oid" : "5f7c94812e296d8251055da2" }, "Alloy" : "LDS-1164", "Life (h) at 982 C/ 241 MPa" : 251.69999999999998863, "Life (h) at 982 C/ 207 MPa" : 803.29999999999995453, "Life (h) at 1093 C/ 124 MPa" : "286.95, 303.45, mean=295.2", "Life (h) at 1093 C/ 110 MPa" : "620.7, 690.9, mean=655.8", "Source" : "2013MacKay", "Table" : "Table 3. Creep rupture lives for single crystal alloys." }
# { "_id" : { "$oid" : "5f7c948c2e296d8251056630" }, "Alloy" : "LDS-1101+Hf", "Life (h) at 982 C/ 241 MPa" : "180.15, 227.0, mean=203.58", "Life (h) at 982 C/ 207 MPa" : 576.14999999999997726, "Life (h) at 1093 C/ 124 MPa" : "271.4, 333.7, mean=302.55", "Life (h) at 1093 C/ 110 MPa" : "696.6, 712.5, mean=704.55", "Source" : "2013MacKay", "Table" : "Table 3. Creep rupture lives for single crystal alloys." }
# ...
# { "_id" : { "$oid" : "5f7c9c862e296d82510b1368" }, "Alloy" : "SC2111", "γ′ size (μm)" : "0.32±0.09", "γ channel width (nm)" : "42.9±13.3", "γ′ volume fraction (%)" : "67.1±3.6", "γ-γ′ lattice misfit (%)" : "−0.21", "1.0% creep life (h)" : 69, "Dislocation spacing (nm)" : "40±6", "Creep life (h)" : 237, "Minimum creep rate (s−1)" : "2.4×10−8", "TCP volume fraction (%)b" : "None", "γ′ volume fraction (%)c" : "58.2±1.3", "Source" : "2017Feng", "Table" : "Table 2. Microstructure features, creep rupture and interrupted lives during creep process at 950 °C and 400 MPa in experimental alloys." }
# { "_id" : { "$oid" : "5f7c9c932e296d82510b1b6b" }, "Alloy" : "SC1211", "γ′ size (μm)" : "0.29±0.06", "γ channel width (nm)" : "52.3±26.1", "γ′ volume fraction (%)" : "58.5±3.9", "γ-γ′ lattice misfit (%)" : "−0.36", "1.0% creep life (h)" : 33, "Dislocation spacing (nm)" : "38±3", "Creep life (h)" : 122, "Minimum creep rate (s−1)" : "4.5×10−8", "TCP volume fraction (%)b" : "2.70±0.10", "γ′ volume fraction (%)c" : "49.6±0.8", "Source" : "2017Feng", "Table" : "Table 2. Microstructure features, creep rupture and interrupted lives during creep process at 950 °C and 400 MPa in experimental alloys." }
# { "_id" : { "$oid" : "5f7c9c9f2e296d82510b2f3e" }, "Alloy" : "SC1121", "γ′ size (μm)" : "0.30±0.07", "γ channel width (nm)" : "43.7±18.0", "γ′ volume fraction (%)" : "63.6±1.9", "γ-γ′ lattice misfit (%)" : "−0.25", "1.0% creep life (h)" : 67, "Dislocation spacing (nm)" : "29±6", "Creep life (h)" : 154, "Minimum creep rate (s−1)" : "3.7×10−8", "TCP volume fraction (%)b" : "1.33±0.08", "γ′ volume fraction (%)c" : "60.8±1.0", "Source" : "2017Feng", "Table" : "Table 2. Microstructure features, creep rupture and interrupted lives during creep process at 950 °C and 400 MPa in experimental alloys." }
# { "_id" : { "$oid" : "5f7c9caa2e296d82510b37d7" }, "Alloy" : "SC1112", "γ′ size (μm)" : "0.30±0.09", "γ channel width (nm)" : "40.4±13.3", "γ′ volume fraction (%)" : "66.3±2.8", "γ-γ′ lattice misfit (%)" : "−0.33", "1.0% creep life (h)" : 151, "Dislocation spacing (nm)" : "31±4", "Creep life (h)" : 302, "Minimum creep rate (s−1)" : "6.7×10−9", "TCP volume fraction (%)b" : "None", "γ′ volume fraction (%)c" : "62.8±0.8", "Source" : "2017Feng", "Table" : "Table 2. Microstructure features, creep rupture and interrupted lives during creep process at 950 °C and 400 MPa in experimental alloys." }
# { "_id" : { "$oid" : "5f7c9cb42e296d82510b3e37" }, "Alloy" : "SC2212", "γ′ size (μm)" : "0.28±0.06", "γ channel width (nm)" : "55.3±31.0", "γ′ volume fraction (%)" : "56.7±1.7", "γ-γ′ lattice misfit (%)" : "−0.23", "1.0% creep life (h)" : 48, "Dislocation spacing (nm)" : "–", "Creep life (h)" : 121, "Minimum creep rate (s−1)" : "5.0×10−8", "TCP volume fraction (%)b" : "None", "γ′ volume fraction (%)c" : "53.6±0.3", "Source" : "2017Feng", "Table" : "Table 2. Microstructure features, creep rupture and interrupted lives during creep process at 950 °C and 400 MPa in experimental alloys." }
# { "_id" : { "$oid" : "5f7c9cbf2e296d82510b452f" }, "Alloy" : "SC2122", "γ′ size (μm)" : "0.32±0.08", "γ channel width (nm)" : "40.7±16.2", "γ′ volume fraction (%)" : "66.2±1.6", "γ-γ′ lattice misfit (%)" : "−0.55", "1.0% creep life (h)" : 173, "Dislocation spacing (nm)" : "30±7", "Creep life (h)" : 328, "Minimum creep rate (s−1)" : "2.7×10−9", "TCP volume fraction (%)b" : "None", "γ′ volume fraction (%)c" : "60.0±1.7", "Source" : "2017Feng", "Table" : "Table 2. Microstructure features, creep rupture and interrupted lives during creep process at 950 °C and 400 MPa in experimental alloys." }
# { "_id" : { "$oid" : "5f7c9cca2e296d82510b4be8" }, "Statistic" : "Amid, midpoint", "γ′ size (μm)" : 0.40500000000000002665, "γ′ volume fraction at 982 °C" : 0.63770000000000004459, "γ′ volume fraction at 1093 °C" : 0.52915000000000000924, "γ−γ‘ lattice mismatch (%)" : -0.13950000000000001288, "Source" : "2013MacKay", "Table" : "Table 4. Normalized microstructural parameter statistics." }
# { "_id" : { "$oid" : "5f7c9cd72e296d82510b55ca" }, "Statistic" : "ΔA/2, half-range", "γ′ size (μm)" : 0.15499999999999999889, "γ′ volume fraction at 982 °C" : 0.036799999999999999378, "γ′ volume fraction at 1093 °C" : 0.059150000000000001188, "γ−γ‘ lattice mismatch (%)" : 0.27650000000000002354, "Source" : "2013MacKay", "Table" : "Table 4. Normalized microstructural parameter statistics." }
# { "_id" : { "$oid" : "5f7c9ce42e296d82510b5fd5" }, "NO." : 1, "Stress (MPa)" : 160, "Notched" : "No", "Lifetime (h)" : 62, "Rupture strain (%)" : 22.600000000000001421, "Elongation (%)" : 20.100000000000001421, "Reduction of area (%)" : 51.200000000000002842, "FE calculation rupture life (h)" : 62, "Source" : "2014Yue", "Table" : "Table 3. The experimental results of DD6 Ni-based single crystal superalloy at 1100 °C." }
# { "_id" : { "$oid" : "5f7c9cf02e296d82510b66c8" }, "NO." : 2, "Stress (MPa)" : 160, "Notched" : "Yes", "Lifetime (h)" : 230.69999999999998863, "Rupture strain (%)" : 4, "Elongation (%)" : 1.2600000000000000089, "Reduction of area (%)" : 5.5, "FE calculation rupture life (h)" : 262.39999999999997726, "Source" : "2014Yue", "Table" : "Table 3. The experimental results of DD6 Ni-based single crystal superalloy at 1100 °C." }
# { "_id" : { "$oid" : "5f7c9d0b2e296d82510b7947" }, "NO." : 3, "Stress (MPa)" : 160, "Notched" : "Yes", "Lifetime (h)" : 234.40000000000000568, "Rupture strain (%)" : 6.5, "Elongation (%)" : 2.2000000000000001776, "Reduction of area (%)" : 7.0999999999999996447, "FE calculation rupture life (h)" : "", "Source" : "2014Yue", "Table" : "Table 3. The experimental results of DD6 Ni-based single crystal superalloy at 1100 °C." }
# { "_id" : { "$oid" : "5f7c9d162e296d82510b823e" }, "NO." : 4, "Stress (MPa)" : 200, "Notched" : "No", "Lifetime (h)" : 16.800000000000000711, "Rupture strain (%)" : 31.5, "Elongation (%)" : 26.399999999999998579, "Reduction of area (%)" : 53.100000000000001421, "FE calculation rupture life (h)" : 16.649999999999998579, "Source" : "2014Yue", "Table" : "Table 3. The experimental results of DD6 Ni-based single crystal superalloy at 1100 °C." }
# { "_id" : { "$oid" : "5f7c9d202e296d82510b8a67" }, "NO." : 5, "Stress (MPa)" : 200, "Notched" : "Yes", "Lifetime (h)" : 79.099999999999994316, "Rupture strain (%)" : 1.3000000000000000444, "Elongation (%)" : 0.76000000000000000888, "Reduction of area (%)" : 4.0999999999999996447, "FE calculation rupture life (h)" : 88, "Source" : "2014Yue", "Table" : "Table 3. The experimental results of DD6 Ni-based single crystal superalloy at 1100 °C." }
# { "_id" : { "$oid" : "5f7c9d2c2e296d82510b90cf" }, "NO." : 6, "Stress (MPa)" : 200, "Notched" : "Yes", "Lifetime (h)" : 100.79999999999999716, "Rupture strain (%)" : 2.2000000000000001776, "Elongation (%)" : 1.2600000000000000089, "Reduction of area (%)" : 5.1600000000000001421, "FE calculation rupture life (h)" : "", "Source" : "2014Yue", "Table" : "Table 3. The experimental results of DD6 Ni-based single crystal superalloy at 1100 °C." }
# { "_id" : { "$oid" : "5f7c9d372e296d82510b97e3" }, "Alloy" : "IC21", "Test condition" : "1100 °C/137 MPa", "Creep rupture life /h" : "170.57 / 159.2", "Density g/cm3" : 7.9900000000000002132, "Source" : "2015Li", "Table" : "Creep properties of some single crystal superalloys under different test conditions" }
# { "_id" : { "$oid" : "5f7c9d552e296d82510bae4c" }, "0" : 159.19999999999998863, "100" : 87.709999999999993747, "300" : 123.18999999999999773, "500" : 48.270000000000003126, "Thermal exposure time (h)" : "Stress-rupture life (h)", "Source" : "2015Li", "Table" : "Table 2. Stress-rupture properties of IC21 alloy after thermal exposure at 1100 °C under the test condition of1100 °C/137 MPa." }
# { "_id" : { "$oid" : "5f7c9d602e296d82510bb42f" }, "0" : 6.7000000000000001776, "100" : 10.730000000000000426, "300" : 9.2100000000000008527, "500" : 10.339999999999999858, "Thermal exposure time (h)" : "Elongation(δ) (%)", "Source" : "2015Li", "Table" : "Table 2. Stress-rupture properties of IC21 alloy after thermal exposure at 1100 °C under the test condition of1100 °C/137 MPa." }
# { "_id" : { "$oid" : "5f7c9d6b2e296d82510bba8b" }, "0" : 19.760000000000001563, "100" : 29.469999999999998863, "300" : 26.809999999999998721, "500" : 49.200000000000002842, "Thermal exposure time (h)" : "Area reduction (ψ) (%)", "Source" : "2015Li", "Table" : "Table 2. Stress-rupture properties of IC21 alloy after thermal exposure at 1100 °C under the test condition of1100 °C/137 MPa." }
# { "_id" : { "$oid" : "5f7c9d782e296d82510bc4ac" }, "SC superalloy" : "900 °C/445 MPa", "t (h)-[001]" : 234.5, "δ (%)-[001]" : 24.800000000000000711, "t (h)-[011]" : 34.799999999999997158, "δ (%)-[011]" : 5.7999999999999998224, "t (h)-[111]" : 127.09999999999999432, "δ (%)-[111]" : 39.100000000000001421, "Source" : "2016Jin", "Table" : "Table 1. Stress rupture properties of the SC superalloy specimens with three orientations: t characterizes the rupture lifetime and marks the rupture elongation" }
# { "_id" : { "$oid" : "5f7c9d842e296d82510bcc10" }, "SC superalloy" : "1100 °C/100 Mpa", "t (h)-[001]" : 395.69999999999998863, "δ (%)-[001]" : 10.199999999999999289, "t (h)-[011]" : 116.29999999999999716, "δ (%)-[011]" : 17.300000000000000711, "t (h)-[111]" : 522.60000000000002274, "δ (%)-[111]" : 3.7000000000000001776, "Source" : "2016Jin", "Table" : "Table 1. Stress rupture properties of the SC superalloy specimens with three orientations: t characterizes the rupture lifetime and marks the rupture elongation" }
# { "_id" : { "$oid" : "5f7c9d9b2e296d82510bdde9" }, "NO." : "P1", "Orientation" : "[001]", "Misorientation" : 2.2999999999999998224, "Lifetime/h" : 198.09999999999999432, "Rupture strain/%" : 0.81999999999999995115, "Elongation/%" : 0.6500000000000000222, "Reduction of area/%" : 1.8999999999999999112, "Source" : "2017Zhixun", "Table" : "Table 3. The experimental results of DD6 Ni-based single crystal at 980 °C/400 MPa." }
# { "_id" : { "$oid" : "5f7c9da52e296d82510be359" }, "NO." : "P2", "Orientation" : "[001]", "Misorientation" : 3.1000000000000000888, "Lifetime/h" : 208.90000000000000568, "Rupture strain/%" : 1.5, "Elongation/%" : 0.73999999999999999112, "Reduction of area/%" : 1.6999999999999999556, "Source" : "2017Zhixun", "Table" : "Table 3. The experimental results of DD6 Ni-based single crystal at 980 °C/400 MPa." }
# { "_id" : { "$oid" : "5f7c9db02e296d82510beb46" }, "NO." : "P3", "Orientation" : "[001]", "Misorientation" : 1.6999999999999999556, "Lifetime/h" : 205.59999999999999432, "Rupture strain/%" : 1.1999999999999999556, "Elongation/%" : 0.70999999999999996447, "Reduction of area/%" : 1.6999999999999999556, "Source" : "2017Zhixun", "Table" : "Table 3. The experimental results of DD6 Ni-based single crystal at 980 °C/400 MPa." }
# { "_id" : { "$oid" : "5f7c9db92e296d82510bf268" }, "NO." : "P4", "Orientation" : "[011]", "Misorientation" : 1.6000000000000000888, "Lifetime/h" : 224.19999999999998863, "Rupture strain/%" : 0.75, "Elongation/%" : 1.1200000000000001066, "Reduction of area/%" : 8.5999999999999996447, "Source" : "2017Zhixun", "Table" : "Table 3. The experimental results of DD6 Ni-based single crystal at 980 °C/400 MPa." }
# { "_id" : { "$oid" : "5f7c9dc42e296d82510bfa12" }, "NO." : "P5", "Orientation" : "[011]", "Misorientation" : 2.2000000000000001776, "Lifetime/h" : 231.09999999999999432, "Rupture strain/%" : 0.80000000000000004441, "Elongation/%" : 1.3300000000000000711, "Reduction of area/%" : 8.9000000000000003553, "Source" : "2017Zhixun", "Table" : "Table 3. The experimental results of DD6 Ni-based single crystal at 980 °C/400 MPa." }
# { "_id" : { "$oid" : "5f7c9dce2e296d82510c03cf" }, "NO." : "P6", "Orientation" : "[011]", "Misorientation" : 3.1000000000000000888, "Lifetime/h" : 236.40000000000000568, "Rupture strain/%" : 0.81999999999999995115, "Elongation/%" : 1.3400000000000000799, "Reduction of area/%" : 9, "Source" : "2017Zhixun", "Table" : "Table 3. The experimental results of DD6 Ni-based single crystal at 980 °C/400 MPa." }
# { "_id" : { "$oid" : "5f7c9ddb2e296d82510c0bf5" }, "NO." : "P7", "Orientation" : [ 111 ], "Misorientation" : 3.6000000000000000888, "Lifetime/h" : 243.5, "Rupture strain/%" : 0.68000000000000004885, "Elongation/%" : 0.94999999999999995559, "Reduction of area/%" : 5.7999999999999998224, "Source" : "2017Zhixun", "Table" : "Table 3. The experimental results of DD6 Ni-based single crystal at 980 °C/400 MPa." }
# { "_id" : { "$oid" : "5f7c9de62e296d82510c134e" }, "NO." : "P8", "Orientation" : [ 111 ], "Misorientation" : 2.8999999999999999112, "Lifetime/h" : 285.69999999999998863, "Rupture strain/%" : 0.80000000000000004441, "Elongation/%" : 1.1799999999999999378, "Reduction of area/%" : 6.5, "Source" : "2017Zhixun", "Table" : "Table 3. The experimental results of DD6 Ni-based single crystal at 980 °C/400 MPa." }
# { "_id" : { "$oid" : "5f7c9df02e296d82510c1a88" }, "NO." : "P9", "Orientation" : [ 111 ], "Misorientation" : 1.8999999999999999112, "Lifetime/h" : 254.19999999999998863, "Rupture strain/%" : 0.71999999999999997335, "Elongation/%" : 1.0500000000000000444, "Reduction of area/%" : 6.0999999999999996447, "Source" : "2017Zhixun", "Table" : "Table 3. The experimental results of DD6 Ni-based single crystal at 980 °C/400 MPa." }
# { "_id" : { "$oid" : "5f7c9e002e296d82510c253a" }, "Temp/P" : "1100 °C/150MPa", "Alloy" : "0Ru", "tfa (h)" : 156.90000000000000568, "tsa (h)" : 77.900000000000005684, "tta (h)" : 55.700000000000002842, "ts/tf" : "49.60%", "tt/tf" : "35.50%", "Source" : "2011 Jin", "Table" : "Table 3. The time spans of secondary and tertiary stages and their percentage in the whole creep rupture life of each creep curve under both conditions." }
# { "_id" : { "$oid" : "5f7c9e1a2e296d82510c3a7c" }, "Temp/P" : "1100 °C/150MPa", "Alloy" : "3Ru", "tfa (h)" : 211.19999999999998863, "tsa (h)" : 105.40000000000000568, "tta (h)" : 75.5, "ts/tf" : "49.90%", "tt/tf" : "35.70%", "Source" : "2011 Jin", "Table" : "Table 3. The time spans of secondary and tertiary stages and their percentage in the whole creep rupture life of each creep curve under both conditions." }
# { "_id" : { "$oid" : "5f7c9e252e296d82510c4291" }, "Temp/P" : "1000 °C/310MPa", "Alloy" : "0Ru", "tfa (h)" : 80.099999999999994316, "tsa (h)" : 18.399999999999998579, "tta (h)" : 54.5, "ts/tf" : "23.00%", "tt/tf" : "68.00%", "Source" : "2011 Jin", "Table" : "Table 3. The time spans of secondary and tertiary stages and their percentage in the whole creep rupture life of each creep curve under both conditions." }
# { "_id" : { "$oid" : "5f7c9e3d2e296d82510c5434" }, "Temp/P" : "1000 °C/310MPa", "Alloy" : "3Ru", "tfa (h)" : 127.09999999999999432, "tsa (h)" : 40, "tta (h)" : 74.200000000000002842, "ts/tf" : "31.50%", "tt/tf" : "58.40%", "Source" : "2011 Jin", "Table" : "Table 3. The time spans of secondary and tertiary stages and their percentage in the whole creep rupture life of each creep curve under both conditions." }
# { "_id" : { "$oid" : "5f80a390d34d780c0d3c1132" }, "Alloy" : "TMS-2004", "Ni" : 59.899999999999998579, "Co" : 12, "Cr" : 3, "Mo" : 2, "W" : 6, "Al" : 6, "Ta" : 6, "Hf" : 0.10000000000000000555, "Re" : 5, "Source" : "2004 Murakumo", "Table" : "Table 1. Chemical composition (wt%) of y and y`phases in TMS-75 calculated by ADP" }
# { "_id" : { "$oid" : "5f80bb73f3f9675c914126f2" }, "Alloy" : "TMS-2004", "Ni" : 59.899999999999998579, "Co" : 12, "Cr" : 3, "Mo" : 2, "W" : 6, "Al" : 6, "Ta" : 6, "Hf" : 0.10000000000000000555, "Re" : 5, "Source" : "2004 Murakumo", "Table" : "Table 1. Chemical composition (wt%) of y and y`phases in TMS-75 calculated by ADP" }
# Done! Exported a total of 144 lines.

# %%
 import <- mongo(collection = "mre", db = "Ni-Alloys", 
               url = url_path, 
               verbose = TRUE)

# %%
import$count('{}')
# Out:
# [1] 0
